# %% [markdown]
# # Data Analysis with CSVs

# %% [markdown]
# In this lesson, we'll complete a full data analysis with a raw data file. **Comma Separated Values** files, known as CSVs, are one of the most common file formats for storing tabular data. In this lesson, we'll show you how to load one into memory and work with it using Python.

# %% [markdown]
# # Objectives

# %% [markdown]
# Perform a complete data analysis by...
#
# - Creating a Python data structure from a .csv file
# - Exploring and cleaning the data
# - Conducting descriptive analysis
# - Visualizing the results

# %% [markdown]
# # Loading a CSV

# %% [markdown]
# The before you can work with a CSV file, you need to load it into memory.
#
# We'll be working with food data! Data source: https://www.kaggle.com/datasets/openfoodfacts/world-food-facts (version we're using has been lightly cleaned and edited for clarity, and because we don't need all 163 columns)

# %% [markdown]
# ## First up - to the Terminal!

# %% [markdown]
# ## Get the File Path

# %% [markdown]
# Make sure you have the path to your data file. For this example, it is in the data folder of Phase1 in this repository.
#
# Open a new Terminal window (one that doesn't have Jupyter running) and check out the _relative_ location and path between this notebook and the `OpenFoodFacts.csv` data file.

# %% [markdown]
# Now, let's save that relative path here, as a string variable.
#
# We use `.` to indicate the current folder when working within this notebook.

# %%
# !ls
# Out:
# 01_InstructorKickoff.pdf
# 02_DataScienceToolkit.pdf
# 03_IntroducingTheTerminal.pdf
# 04_IntroducingGitandGitHub.pdf
# 05_CreatingRepositoriesandCollaboratingwithGit.pdf
# 06_PythonDataManipulation.ipynb
# 07_DataAnalysis_CSV.ipynb
# 08_DataAnalysis_JSON.ipynb
# 09_PandasDataframes.ipynb
# 10_Plotting_with_Pandas.ipynb
# 11_Pandas_DataCleaning.ipynb
# 12_Aggregating_Combining_Dataframes.ipynb
# 13_Descriptive_Stats.ipynb
# data
# images
# src

# %%
# !ls data
# Out:
# 2019_Census_US_Population_Data_By_State_Lat_Long.csv
# Austin_Animal_Center_Intakes-clean-year.csv
# Austin_Animal_Center_Intakes_022822.csv
# Austin_Animal_Center_Outcomes_022822.csv
# BankChurners.csv
# Datafiniti_Fast_Food.csv
# OpenFoodFacts.csv
# bundesliga.csv
# bundesliga.json
# classic-rock-song-list.csv
# dataset_Facebook.csv
# ds_chars.csv
# heart.csv
# new_releases.json
# offset_newreleases.p
# plants.json
# pop_soda_data.csv
# preferences.csv
# states.csv

# %%
csv_file_path = './data/OpenFoodFacts.csv'

# %% [markdown]
# ## Inspecting CSV files

# %% [markdown]
# In a CSV file, each line represents one row of tabular data, and consecutive values in that row are separated by a comma. Often, the first row contains the column names separated by commas, also known as field names. Let's confirm that this is the case and learn about our dataset by printing the first five lines of the file.

# %% [markdown]
# We can inspect the data directly in our terminal! Use the bash command `head` with the flag `-n 2` to check out those first two rows.

# %%
# !head -n 3 data/OpenFoodFacts.csv
# Out:
# product_name,brands,created_date,last_modified_date,serving_size,energy_100g,fat_100g,carbohydrates_100g,sugars_100g,proteins_100g
# Banana Chips Sweetened (Whole),,2017-03-09,2017-03-09,28.0 g,2243.0,28.57,64.29,14.29,3.57
# Peanuts,Torn & Glasser,2017-03-09,2017-03-09,28.0 g,1941.0,17.86,60.71,17.86,17.86

# %% [markdown]
# ### Printing Lines in Python

# %% [markdown]
# We use the `with open()` syntax to easily open and read the file in the notebook. Using this syntax will automatically close the file once the statement is done running.

# %%
# This code prints the first line of the CSV file

with open(csv_file_path) as csvfile:
    print(csvfile.readline())
# Out:
# product_name,brands,created_date,last_modified_date,serving_size,energy_100g,fat_100g,carbohydrates_100g,sugars_100g,proteins_100g

# %% [markdown]
# Next, we can print the second line to look at an example of one observation from our dataset.

# %%
# This code prints the second line of the CSV file

with open(csv_file_path) as csvfile:
    csvfile.readline()
    print(csvfile.readline())
# Out:
# Banana Chips Sweetened (Whole),,2017-03-09,2017-03-09,28.0 g,2243.0,28.57,64.29,14.29,3.57

# %% [markdown]
# ### Discussion

# %% [markdown]
# Based on these two lines, what can we infer about the contents of the data file? What questions arise for you about the data?
#
# - We have column headers are first row, and each row looks like a unique product

# %% [markdown]
# ## Using the `csv` module

# %% [markdown]
# The [`csv` module](https://docs.python.org/3/library/csv.html) lets us easily process data in CSV files. We will use it to read each row in the `.csv` file and store its information in a Python object we can use for further analysis.

# %%
import csv

# %% [markdown]
# The [`csv.DictReader`](https://docs.python.org/3/library/csv.html#csv.DictReader) object is a file reader, reading each row and then converting it to a dictionary. By default, it turns each row into a dictionary, using the field names from the first row as the keys.

# %%
# Print OrderedDict from first row of CSV file 

with open(csv_file_path) as csvfile:
    reader = csv.DictReader(csvfile)
    print(next(reader))
# Out:
# {'product_name': 'Banana Chips Sweetened (Whole)', 'brands': '', 'created_date': '2017-03-09', 'last_modified_date': '2017-03-09', 'serving_size': '28.0 g', 'energy_100g': '2243.0', 'fat_100g': '28.57', 'carbohydrates_100g': '64.29', 'sugars_100g': '14.29', 'proteins_100g': '3.57'}

# %% [markdown]
# Let's get all of the data out of our file and into dictionaries, and store those dictionaries in a new list called `products`.

# %%
# One way
with open(csv_file_path, encoding='utf-8') as open_file:
    products = list(csv.DictReader(open_file, ))

# %%
products
# Out:
# [{'product_name': 'Banana Chips Sweetened (Whole)',
#   'brands': '',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2243.0',
#   'fat_100g': '28.57',
#   'carbohydrates_100g': '64.29',
#   'sugars_100g': '14.29',
#   'proteins_100g': '3.57'},
#  {'product_name': 'Peanuts',
#   'brands': 'Torn & Glasser',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '1941.0',
#   'fat_100g': '17.86',
#   'carbohydrates_100g': '60.71',
#   'sugars_100g': '17.86',
#   'proteins_100g': '17.86'},
#  {'product_name': 'Organic Salted Nut Mix',
#   'brands': 'Grizzlies',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2540.0',
#   'fat_100g': '57.14',
#   'carbohydrates_100g': '17.86',
#   'sugars_100g': '3.57',
#   'proteins_100g': '17.86'},
#  {'product_name': 'Organic Polenta',
#   'brands': "Bob's Red Mill",
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '35.0 g',
#   'energy_100g': '1552.0',
#   'fat_100g': '1.43',
#   'carbohydrates_100g': '77.14',
#   'sugars_100g': '',
#   'proteins_100g': '8.57'},
#  {'product_name': 'Breadshop Honey Gone Nuts Granola',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '52.0 g',
#   'energy_100g': '1933.0',
#   'fat_100g': '18.27',
#   'carbohydrates_100g': '63.46',
#   'sugars_100g': '11.54',
#   'proteins_100g': '13.46'},
#  {'product_name': 'Organic Long Grain White Rice',
#   'brands': 'Lundberg',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1490.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '80.0',
#   'sugars_100g': '',
#   'proteins_100g': '8.89'},
#  {'product_name': 'Organic Muesli',
#   'brands': "Daddy's Muesli",
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '64.0 g',
#   'energy_100g': '1833.0',
#   'fat_100g': '18.75',
#   'carbohydrates_100g': '57.81',
#   'sugars_100g': '15.62',
#   'proteins_100g': '14.06'},
#  {'product_name': 'Organic Dark Chocolate Minis',
#   'brands': 'Equal Exchange',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2406.0',
#   'fat_100g': '37.5',
#   'carbohydrates_100g': '55.0',
#   'sugars_100g': '42.5',
#   'proteins_100g': '5.0'},
#  {'product_name': 'Organic Sunflower Oil',
#   'brands': 'Napa Valley Naturals',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '14.0 g',
#   'energy_100g': '3586.0',
#   'fat_100g': '100.0',
#   'carbohydrates_100g': '',
#   'sugars_100g': '',
#   'proteins_100g': ''},
#  {'product_name': 'Organic Adzuki Beans',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '48.0 g',
#   'energy_100g': '1393.0',
#   'fat_100g': '1.04',
#   'carbohydrates_100g': '62.5',
#   'sugars_100g': '',
#   'proteins_100g': '22.92'},
#  {'product_name': 'Organic Penne Pasta',
#   'brands': 'Gardentime',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '57.0 g',
#   'energy_100g': '1540.0',
#   'fat_100g': '1.75',
#   'carbohydrates_100g': '73.68',
#   'sugars_100g': '',
#   'proteins_100g': '14.04'},
#  {'product_name': 'Zen Party Mix',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2230.0',
#   'fat_100g': '36.67',
#   'carbohydrates_100g': '36.67',
#   'sugars_100g': '3.33',
#   'proteins_100g': '16.67'},
#  {'product_name': 'Organic Golden Flax Seeds',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '21.0 g',
#   'energy_100g': '2590.0',
#   'fat_100g': '42.86',
#   'carbohydrates_100g': '38.1',
#   'sugars_100g': '',
#   'proteins_100g': '19.05'},
#  {'product_name': 'Organic Spicy Punks',
#   'brands': 'Eden',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '33.0 g',
#   'energy_100g': '2536.0',
#   'fat_100g': '48.48',
#   'carbohydrates_100g': '15.15',
#   'sugars_100g': '',
#   'proteins_100g': '30.3'},
#  {'product_name': 'Cinnamon Nut Granola',
#   'brands': 'Grizzlies',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '55.0 g',
#   'energy_100g': '1824.0',
#   'fat_100g': '18.18',
#   'carbohydrates_100g': '60.0',
#   'sugars_100g': '21.82',
#   'proteins_100g': '14.55'},
#  {'product_name': 'Organic Hazelnuts',
#   'brands': 'Grizzlies',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2632.0',
#   'fat_100g': '60.71',
#   'carbohydrates_100g': '17.86',
#   'sugars_100g': '3.57',
#   'proteins_100g': '14.29'},
#  {'product_name': 'Organic Sweetened Banana Chips',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2092.0',
#   'fat_100g': '26.67',
#   'carbohydrates_100g': '66.67',
#   'sugars_100g': '16.67',
#   'proteins_100g': '3.33'},
#  {'product_name': 'Lotus Organic Brown Jasmine Rice',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1582.0',
#   'fat_100g': '2.22',
#   'carbohydrates_100g': '77.78',
#   'sugars_100g': '2.22',
#   'proteins_100g': '8.89'},
#  {'product_name': 'Organic Oat Groats',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '42.0 g',
#   'energy_100g': '1096.0',
#   'fat_100g': '5.95',
#   'carbohydrates_100g': '66.67',
#   'sugars_100g': '2.38',
#   'proteins_100g': '16.67'},
#  {'product_name': 'Energy Power Mix',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '1464.0',
#   'fat_100g': '17.5',
#   'carbohydrates_100g': '42.5',
#   'sugars_100g': '32.5',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Antioxidant Mix - Berries & Chocolate',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2092.0',
#   'fat_100g': '33.33',
#   'carbohydrates_100g': '46.67',
#   'sugars_100g': '30.0',
#   'proteins_100g': '13.33'},
#  {'product_name': 'Organic Quinoa Coconut Granola With Mango',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '55.0 g',
#   'energy_100g': '1674.0',
#   'fat_100g': '10.91',
#   'carbohydrates_100g': '69.09',
#   'sugars_100g': '27.27',
#   'proteins_100g': '10.91'},
#  {'product_name': 'Fire Roasted Hatch Green Chile Almonds',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2372.0',
#   'fat_100g': '50.0',
#   'carbohydrates_100g': '23.33',
#   'sugars_100g': '6.67',
#   'proteins_100g': '6.67'},
#  {'product_name': 'Peanut Butter Power Chews',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-10',
#   'last_modified_date': '2017-03-10',
#   'serving_size': '45.0 g',
#   'energy_100g': '1954.0',
#   'fat_100g': '20.0',
#   'carbohydrates_100g': '60.0',
#   'sugars_100g': '33.33',
#   'proteins_100g': '8.89'},
#  {'product_name': 'Real Salt Granular',
#   'brands': 'Redmond',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '1.4 g',
#   'energy_100g': '',
#   'fat_100g': '',
#   'carbohydrates_100g': '',
#   'sugars_100g': '',
#   'proteins_100g': ''},
#  {'product_name': 'Organic Unswt Berry Coconut Granola',
#   'brands': 'New England Naturals',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '54.0 g',
#   'energy_100g': '1548.0',
#   'fat_100g': '22.22',
#   'carbohydrates_100g': '57.41',
#   'sugars_100g': '5.56',
#   'proteins_100g': '12.96'},
#  {'product_name': 'Roasted Salted Black Pepper Cashews',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2372.0',
#   'fat_100g': '46.67',
#   'carbohydrates_100g': '30.0',
#   'sugars_100g': '6.67',
#   'proteins_100g': '16.67'},
#  {'product_name': 'Thai Curry Roasted Cashews',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2372.0',
#   'fat_100g': '43.33',
#   'carbohydrates_100g': '30.0',
#   'sugars_100g': '6.67',
#   'proteins_100g': '16.67'},
#  {'product_name': 'Wasabi Tamari Almonds',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2230.0',
#   'fat_100g': '46.67',
#   'carbohydrates_100g': '23.33',
#   'sugars_100g': '3.33',
#   'proteins_100g': '20.0'},
#  {'product_name': 'Organic Medium Shredded Coconut',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2230.0',
#   'fat_100g': '30.0',
#   'carbohydrates_100g': '53.33',
#   'sugars_100g': '6.67',
#   'proteins_100g': '6.67'},
#  {'product_name': 'Organic Red Quinoa',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1490.0',
#   'fat_100g': '6.67',
#   'carbohydrates_100g': '64.44',
#   'sugars_100g': '11.11',
#   'proteins_100g': '13.33'},
#  {'product_name': 'Dark Chocolate Coconut Chews',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2092.0',
#   'fat_100g': '35.0',
#   'carbohydrates_100g': '52.5',
#   'sugars_100g': '37.5',
#   'proteins_100g': '5.0'},
#  {'product_name': 'Seventh Heaven Organic Trail Mix',
#   'brands': 'Grizzlies',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2092.0',
#   'fat_100g': '32.14',
#   'carbohydrates_100g': '46.43',
#   'sugars_100g': '35.71',
#   'proteins_100g': '14.29'},
#  {'product_name': 'Organic Unsweetened Granola, Cinnamon Almond',
#   'brands': 'New England Naturals',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '51.0 g',
#   'energy_100g': '1887.0',
#   'fat_100g': '21.57',
#   'carbohydrates_100g': '58.82',
#   'sugars_100g': '3.92',
#   'proteins_100g': '11.76'},
#  {'product_name': 'Organic Blueberry Almond Granola',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '55.0 g',
#   'energy_100g': '1674.0',
#   'fat_100g': '9.09',
#   'carbohydrates_100g': '70.91',
#   'sugars_100g': '29.09',
#   'proteins_100g': '10.91'},
#  {'product_name': 'Sweeteners, Demerara Turbinado Sugar',
#   'brands': 'Wholesome,  Wholesome Sweeteners',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '4.0 g',
#   'energy_100g': '1569.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '100.0',
#   'sugars_100g': '100.0',
#   'proteins_100g': ''},
#  {'product_name': "Aunt Maple's Crunchy Granola",
#   'brands': 'Grizzlies',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '56.0 g',
#   'energy_100g': '2092.0',
#   'fat_100g': '28.57',
#   'carbohydrates_100g': '55.36',
#   'sugars_100g': '23.21',
#   'proteins_100g': '10.71'},
#  {'product_name': 'Organic Coconut Chips',
#   'brands': 'Grizzlies',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '100.0 g',
#   'energy_100g': '2761.0',
#   'fat_100g': '65.0',
#   'carbohydrates_100g': '24.0',
#   'sugars_100g': '7.0',
#   'proteins_100g': '6.0'},
#  {'product_name': 'Organic Black Beans',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1393.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '62.22',
#   'sugars_100g': '2.22',
#   'proteins_100g': '22.22'},
#  {'product_name': 'Organic Whole Grain Emmer Farro',
#   'brands': 'Bluebird Grain',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '47.0 g',
#   'energy_100g': '1515.0',
#   'fat_100g': '2.13',
#   'carbohydrates_100g': '72.34',
#   'sugars_100g': '',
#   'proteins_100g': '12.77'},
#  {'product_name': 'Organic Hard Red Wheat Berries',
#   'brands': 'Bluebird Grain',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '47.0 g',
#   'energy_100g': '1335.0',
#   'fat_100g': '2.13',
#   'carbohydrates_100g': '68.09',
#   'sugars_100g': '',
#   'proteins_100g': '12.77'},
#  {'product_name': "Aunt Ginger's Snappy Granola",
#   'brands': 'Grizzlies',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '56.0 g',
#   'energy_100g': '1941.0',
#   'fat_100g': '17.86',
#   'carbohydrates_100g': '64.29',
#   'sugars_100g': '21.43',
#   'proteins_100g': '10.71'},
#  {'product_name': 'Dark Chocolate Sea Salt & Turbinado Almonds',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2197.0',
#   'fat_100g': '35.0',
#   'carbohydrates_100g': '50.0',
#   'sugars_100g': '37.5',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Divinely Organic Granola',
#   'brands': 'Grizzlies',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '55.0 g',
#   'energy_100g': '1749.0',
#   'fat_100g': '14.55',
#   'carbohydrates_100g': '65.45',
#   'sugars_100g': '21.82',
#   'proteins_100g': '12.73'},
#  {'product_name': 'Organic Black Chia Seeds',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2046.0',
#   'fat_100g': '32.14',
#   'carbohydrates_100g': '42.86',
#   'sugars_100g': '',
#   'proteins_100g': '14.29'},
#  {'product_name': 'Organic French Green Lentils',
#   'brands': 'Crown Pacific Fine Foods',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1490.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '64.44',
#   'sugars_100g': '4.44',
#   'proteins_100g': '26.67'},
#  {'product_name': 'Organic Garbanzo Beans',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '47.0 g',
#   'energy_100g': '1335.0',
#   'fat_100g': '5.32',
#   'carbohydrates_100g': '53.19',
#   'sugars_100g': '8.51',
#   'proteins_100g': '17.02'},
#  {'product_name': 'Organic Green Split Peas',
#   'brands': 'Coombs Family',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1582.0',
#   'fat_100g': '1.11',
#   'carbohydrates_100g': '68.89',
#   'sugars_100g': '',
#   'proteins_100g': '28.89'},
#  {'product_name': 'Organic Small Red Chili Beans',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '36.0 g',
#   'energy_100g': '699.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '63.89',
#   'sugars_100g': '2.78',
#   'proteins_100g': '22.22'},
#  {'product_name': 'Organic Small White Beans',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1674.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '66.67',
#   'sugars_100g': '2.22',
#   'proteins_100g': '24.44'},
#  {'product_name': 'Organic Grey-Green Lentils',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1582.0',
#   'fat_100g': '1.11',
#   'carbohydrates_100g': '66.67',
#   'sugars_100g': '',
#   'proteins_100g': '28.89'},
#  {'product_name': 'Organic Yellow Split Peas',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1582.0',
#   'fat_100g': '1.11',
#   'carbohydrates_100g': '68.89',
#   'sugars_100g': '8.89',
#   'proteins_100g': '28.89'},
#  {'product_name': 'Organic Mung Beans',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '51.0 g',
#   'energy_100g': '1477.0',
#   'fat_100g': '0.98',
#   'carbohydrates_100g': '62.75',
#   'sugars_100g': '',
#   'proteins_100g': '23.53'},
#  {'product_name': 'Organic Baby Lima Beans',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1393.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '62.22',
#   'sugars_100g': '8.89',
#   'proteins_100g': '20.0'},
#  {'product_name': 'Organic Dark Red Kidney Bean',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '46.0 g',
#   'energy_100g': '1272.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '54.35',
#   'sugars_100g': '2.17',
#   'proteins_100g': '19.57'},
#  {'product_name': 'Coconut Almond Granola',
#   'brands': 'Golden Temple',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '55.0 g',
#   'energy_100g': '2054.0',
#   'fat_100g': '25.45',
#   'carbohydrates_100g': '58.18',
#   'sugars_100g': '9.09',
#   'proteins_100g': '10.91'},
#  {'product_name': 'Super Nutty Granola',
#   'brands': 'Golden Temple',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '55.0 g',
#   'energy_100g': '1904.0',
#   'fat_100g': '18.18',
#   'carbohydrates_100g': '63.64',
#   'sugars_100g': '10.91',
#   'proteins_100g': '10.91'},
#  {'product_name': 'Maple Almond Granola',
#   'brands': 'Golden Temple',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '55.0 g',
#   'energy_100g': '1904.0',
#   'fat_100g': '14.55',
#   'carbohydrates_100g': '67.27',
#   'sugars_100g': '12.73',
#   'proteins_100g': '10.91'},
#  {'product_name': '35% Fruit And Fiber Muesli',
#   'brands': 'Golden Temple',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '55.0 g',
#   'energy_100g': '1523.0',
#   'fat_100g': '4.55',
#   'carbohydrates_100g': '70.91',
#   'sugars_100g': '23.64',
#   'proteins_100g': '10.91'},
#  {'product_name': 'Rebel Crunch Granola',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '56.0 g',
#   'energy_100g': '1720.0',
#   'fat_100g': '8.93',
#   'carbohydrates_100g': '73.21',
#   'sugars_100g': '21.43',
#   'proteins_100g': '14.29'},
#  {'product_name': 'Organic Mixed Vegetable Spirals',
#   'brands': 'Gardentime',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '57.0 g',
#   'energy_100g': '1490.0',
#   'fat_100g': '1.75',
#   'carbohydrates_100g': '71.93',
#   'sugars_100g': '',
#   'proteins_100g': '14.04'},
#  {'product_name': 'Tricolor Tortellini',
#   'brands': 'Napoleon',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '65.0 g',
#   'energy_100g': '1611.0',
#   'fat_100g': '9.23',
#   'carbohydrates_100g': '60.0',
#   'sugars_100g': '1.54',
#   'proteins_100g': '13.85'},
#  {'product_name': 'Organic Couscous',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1582.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '80.0',
#   'sugars_100g': '',
#   'proteins_100g': '13.33'},
#  {'product_name': 'Organic Spaghetti',
#   'brands': 'Gardentime',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '56.0 g',
#   'energy_100g': '1569.0',
#   'fat_100g': '2.68',
#   'carbohydrates_100g': '67.86',
#   'sugars_100g': '5.36',
#   'proteins_100g': '12.5'},
#  {'product_name': 'Orzo Rosa Marina',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '58.0 g',
#   'energy_100g': '1443.0',
#   'fat_100g': '1.72',
#   'carbohydrates_100g': '67.24',
#   'sugars_100g': '1.72',
#   'proteins_100g': '12.07'},
#  {'product_name': 'Organic Refined Spelt Flour',
#   'brands': 'Vitaspelt',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '1393.0',
#   'fat_100g': '1.67',
#   'carbohydrates_100g': '70.0',
#   'sugars_100g': '',
#   'proteins_100g': '13.33'},
#  {'product_name': '10-Grain Pancake Mix',
#   'brands': "Bob's Red Mill",
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '58.0 g',
#   'energy_100g': '1297.0',
#   'fat_100g': '1.72',
#   'carbohydrates_100g': '60.34',
#   'sugars_100g': '5.17',
#   'proteins_100g': '13.79'},
#  {'product_name': 'Fine Sea Salt',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '1.5 g',
#   'energy_100g': '',
#   'fat_100g': '',
#   'carbohydrates_100g': '',
#   'sugars_100g': '',
#   'proteins_100g': ''},
#  {'product_name': 'Sweeteners, Organic Fair Trade Sugar',
#   'brands': 'Wholesome,  Wholesome Sweeteners',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '4.0 g',
#   'energy_100g': '1569.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '100.0',
#   'sugars_100g': '100.0',
#   'proteins_100g': ''},
#  {'product_name': 'Organic Refined Unbleached White Flour',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '1536.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '76.67',
#   'sugars_100g': '',
#   'proteins_100g': '10.0'},
#  {'product_name': 'Organic Whole Brown Rice Flour',
#   'brands': 'Fairhaven',
#   'created_date': '2017-03-10',
#   'last_modified_date': '2017-03-10',
#   'serving_size': '31.0 g',
#   'energy_100g': '1891.0',
#   'fat_100g': '3.23',
#   'carbohydrates_100g': '96.77',
#   'sugars_100g': '',
#   'proteins_100g': '12.9'},
#  {'product_name': 'Organic Whole Spelt Flour',
#   'brands': 'Vitaspelt',
#   'created_date': '2017-03-10',
#   'last_modified_date': '2017-03-10',
#   'serving_size': '34.0 g',
#   'energy_100g': '1356.0',
#   'fat_100g': '2.94',
#   'carbohydrates_100g': '67.65',
#   'sugars_100g': '2.94',
#   'proteins_100g': '14.71'},
#  {'product_name': 'Organic Whole Rye Flour',
#   'brands': 'Fairhaven',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '1393.0',
#   'fat_100g': '1.67',
#   'carbohydrates_100g': '73.33',
#   'sugars_100g': '',
#   'proteins_100g': '10.0'},
#  {'product_name': 'Granola Cranberry And Acai',
#   'brands': 'Viva La Salud',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '55.0 g',
#   'energy_100g': '1824.0',
#   'fat_100g': '10.91',
#   'carbohydrates_100g': '74.55',
#   'sugars_100g': '25.45',
#   'proteins_100g': '9.09'},
#  {'product_name': 'Organic Medium Whole Wheat Flour',
#   'brands': 'Fairhaven',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '35.0 g',
#   'energy_100g': '1552.0',
#   'fat_100g': '1.43',
#   'carbohydrates_100g': '62.86',
#   'sugars_100g': '',
#   'proteins_100g': '11.43'},
#  {'product_name': 'Organic Soft Whole Wheat Pastry Flour',
#   'brands': 'Fairhaven',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '1644.0',
#   'fat_100g': '1.79',
#   'carbohydrates_100g': '78.57',
#   'sugars_100g': '',
#   'proteins_100g': '14.29'},
#  {'product_name': 'Peanuts, Mixed Nuts',
#   'brands': 'Northgate Market',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2389.0',
#   'fat_100g': '42.86',
#   'carbohydrates_100g': '25.0',
#   'sugars_100g': '14.29',
#   'proteins_100g': '25.0'},
#  {'product_name': 'Organic Large Raw Whole Cashews',
#   'brands': 'Not A Branded Item',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2648.0',
#   'fat_100g': '50.0',
#   'carbohydrates_100g': '30.0',
#   'sugars_100g': '6.67',
#   'proteins_100g': '16.67'},
#  {'product_name': 'Organic Brown Sesame Seeds',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '36.0 g',
#   'energy_100g': '2439.0',
#   'fat_100g': '50.0',
#   'carbohydrates_100g': '22.22',
#   'sugars_100g': '',
#   'proteins_100g': '16.67'},
#  {'product_name': 'Organic White Sesame Seeds',
#   'brands': 'Not A Branded Item',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '36.0 g',
#   'energy_100g': '2439.0',
#   'fat_100g': '55.56',
#   'carbohydrates_100g': '13.89',
#   'sugars_100g': '',
#   'proteins_100g': '19.44'},
#  {'product_name': 'Almonds Hickory-Smoked',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2690.0',
#   'fat_100g': '57.14',
#   'carbohydrates_100g': '14.29',
#   'sugars_100g': '',
#   'proteins_100g': '21.43'},
#  {'product_name': 'Foods, Spanish Peanuts',
#   'brands': 'Kettle,  Kettle Foods',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2389.0',
#   'fat_100g': '50.0',
#   'carbohydrates_100g': '17.86',
#   'sugars_100g': '3.57',
#   'proteins_100g': '28.57'},
#  {'product_name': 'Foods, Honey Roasted Nut Mix',
#   'brands': 'Kettle,  Kettle Foods',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2389.0',
#   'fat_100g': '46.43',
#   'carbohydrates_100g': '28.57',
#   'sugars_100g': '3.57',
#   'proteins_100g': '21.43'},
#  {'product_name': 'Roasted Salted Sunflower Seeds',
#   'brands': 'Kid Picks',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2766.0',
#   'fat_100g': '57.14',
#   'carbohydrates_100g': '21.43',
#   'sugars_100g': '3.57',
#   'proteins_100g': '21.43'},
#  {'product_name': 'Foods, Deluxe Nut Mix',
#   'brands': 'Kettle,  Kettle Foods',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2540.0',
#   'fat_100g': '57.14',
#   'carbohydrates_100g': '21.43',
#   'sugars_100g': '3.57',
#   'proteins_100g': '17.86'},
#  {'product_name': 'Foods, Honey Roast Nuts & Fruit Mix',
#   'brands': 'Kettle,  Kettle Foods',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '25.0 g',
#   'energy_100g': '2176.0',
#   'fat_100g': '28.0',
#   'carbohydrates_100g': '60.0',
#   'sugars_100g': '32.0',
#   'proteins_100g': '12.0'},
#  {'product_name': 'Organic Raw Walnuts',
#   'brands': 'Kid Picks',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '25.0 g',
#   'energy_100g': '2678.0',
#   'fat_100g': '64.0',
#   'carbohydrates_100g': '12.0',
#   'sugars_100g': '',
#   'proteins_100g': '16.0'},
#  {'product_name': 'Organic Raw Sunflower Seeds',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '33.0 g',
#   'energy_100g': '2218.0',
#   'fat_100g': '42.42',
#   'carbohydrates_100g': '21.21',
#   'sugars_100g': '',
#   'proteins_100g': '18.18'},
#  {'product_name': 'Organic Trail Mix',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '1812.0',
#   'fat_100g': '26.67',
#   'carbohydrates_100g': '46.67',
#   'sugars_100g': '33.33',
#   'proteins_100g': '13.33'},
#  {'product_name': 'Organic Pecan Halves',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.4 g',
#   'energy_100g': '2946.0',
#   'fat_100g': '70.42',
#   'carbohydrates_100g': '14.08',
#   'sugars_100g': '3.52',
#   'proteins_100g': '10.56'},
#  {'product_name': 'Unsalted Dry Roasted Almonds',
#   'brands': 'Unfi',
#   'created_date': '2017-03-10',
#   'last_modified_date': '2017-03-10',
#   'serving_size': '30.0 g',
#   'energy_100g': '2791.0',
#   'fat_100g': '56.67',
#   'carbohydrates_100g': '20.0',
#   'sugars_100g': '6.67',
#   'proteins_100g': '26.67'},
#  {'product_name': 'Organic Raw Pumpkin Seeds',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '46.67',
#   'carbohydrates_100g': '13.33',
#   'sugars_100g': '3.33',
#   'proteins_100g': '30.0'},
#  {'product_name': 'Curry Lentil Soup Mix',
#   'brands': 'Taste Adventure',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '52.0 g',
#   'energy_100g': '1289.0',
#   'fat_100g': '1.92',
#   'carbohydrates_100g': '51.92',
#   'sugars_100g': '5.77',
#   'proteins_100g': '25.0'},
#  {'product_name': 'Split Pea Soup Mix',
#   'brands': 'Taste Adventure',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '70.0 g',
#   'energy_100g': '1314.0',
#   'fat_100g': '1.43',
#   'carbohydrates_100g': '57.14',
#   'sugars_100g': '8.57',
#   'proteins_100g': '22.86'},
#  {'product_name': "Whole Wheat 'N Honey Fig Bars",
#   'brands': 'Marin',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '1255.0',
#   'fat_100g': '6.67',
#   'carbohydrates_100g': '56.67',
#   'sugars_100g': '26.67',
#   'proteins_100g': '10.0'},
#  {'product_name': 'Chocolate Nut Crunch',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '1954.0',
#   'fat_100g': '26.67',
#   'carbohydrates_100g': '53.33',
#   'sugars_100g': '36.67',
#   'proteins_100g': '10.0'},
#  {'product_name': 'Milk Chocolate Peanut Butter Malt Balls',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2197.0',
#   'fat_100g': '27.5',
#   'carbohydrates_100g': '60.0',
#   'sugars_100g': '57.5',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Organic Tamari Pumpkin Seed',
#   'brands': 'Woodstock',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '34.0 g',
#   'energy_100g': '2092.0',
#   'fat_100g': '41.18',
#   'carbohydrates_100g': '17.65',
#   'sugars_100g': '2.94',
#   'proteins_100g': '26.47'},
#  {'product_name': 'Yogurt Pretzels',
#   'brands': 'Woodstock',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2092.0',
#   'fat_100g': '20.0',
#   'carbohydrates_100g': '72.5',
#   'sugars_100g': '47.5',
#   'proteins_100g': '5.0'},
#  {'product_name': 'Organic Kamut Flakes',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '941.0',
#   'fat_100g': '1.25',
#   'carbohydrates_100g': '42.5',
#   'sugars_100g': '',
#   'proteins_100g': '10.0'},
#  {'product_name': 'Regular Rolled Oats',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '26.0 g',
#   'energy_100g': '1611.0',
#   'fat_100g': '7.69',
#   'carbohydrates_100g': '65.38',
#   'sugars_100g': '',
#   'proteins_100g': '15.38'},
#  {'product_name': 'Quick Rolled Oats',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '26.0 g',
#   'energy_100g': '1611.0',
#   'fat_100g': '7.69',
#   'carbohydrates_100g': '65.38',
#   'sugars_100g': '',
#   'proteins_100g': '15.38'},
#  {'product_name': 'Organic Bulgur',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '1464.0',
#   'fat_100g': '1.7',
#   'carbohydrates_100g': '75.0',
#   'sugars_100g': '',
#   'proteins_100g': '12.5'},
#  {'product_name': 'Organic Toasted Buckwheat Groats',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '41.0 g',
#   'energy_100g': '1427.0',
#   'fat_100g': '2.44',
#   'carbohydrates_100g': '73.17',
#   'sugars_100g': '',
#   'proteins_100g': '12.2'},
#  {'product_name': 'Organic Rolled Barley Flakes',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '1197.0',
#   'fat_100g': '1.79',
#   'carbohydrates_100g': '64.29',
#   'sugars_100g': '',
#   'proteins_100g': '10.71'},
#  {'product_name': 'Multigrain Cereal Flakes',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '38.0 g',
#   'energy_100g': '1540.0',
#   'fat_100g': '2.63',
#   'carbohydrates_100g': '76.32',
#   'sugars_100g': '',
#   'proteins_100g': '13.16'},
#  {'product_name': '8-Grain Wheat Free Cereal',
#   'brands': "Bob's Red Mill",
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '1569.0',
#   'fat_100g': '6.25',
#   'carbohydrates_100g': '67.5',
#   'sugars_100g': '',
#   'proteins_100g': '12.5'},
#  {'product_name': 'Swiss-Style Muesli',
#   'brands': 'Grizzlies',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '55.0 g',
#   'energy_100g': '1749.0',
#   'fat_100g': '16.36',
#   'carbohydrates_100g': '60.0',
#   'sugars_100g': '16.36',
#   'proteins_100g': '12.73'},
#  {'product_name': 'Organic Hulless Barley',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '46.0 g',
#   'energy_100g': '1548.0',
#   'fat_100g': '2.17',
#   'carbohydrates_100g': '73.91',
#   'sugars_100g': '',
#   'proteins_100g': '13.04'},
#  {'product_name': 'Organic Millet',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '48.0 g',
#   'energy_100g': '1569.0',
#   'fat_100g': '3.12',
#   'carbohydrates_100g': '75.0',
#   'sugars_100g': '',
#   'proteins_100g': '12.5'},
#  {'product_name': 'Organic Popcorn',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '50.0 g',
#   'energy_100g': '1506.0',
#   'fat_100g': '4.0',
#   'carbohydrates_100g': '72.0',
#   'sugars_100g': '',
#   'proteins_100g': '12.0'},
#  {'product_name': 'Organic Soft White Wheat Berries',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '47.0 g',
#   'energy_100g': '1423.0',
#   'fat_100g': '2.13',
#   'carbohydrates_100g': '72.34',
#   'sugars_100g': '',
#   'proteins_100g': '14.89'},
#  {'product_name': 'Organic Pearled Barley',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '50.0 g',
#   'energy_100g': '1506.0',
#   'fat_100g': '2.0',
#   'carbohydrates_100g': '78.0',
#   'sugars_100g': '',
#   'proteins_100g': '10.0'},
#  {'product_name': 'Organic Wheat Bran',
#   'brands': 'Guistos',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '15.0 g',
#   'energy_100g': '837.0',
#   'fat_100g': '3.33',
#   'carbohydrates_100g': '66.67',
#   'sugars_100g': '',
#   'proteins_100g': '13.33'},
#  {'product_name': 'Organic Raw Buckwheat Groats',
#   'brands': '',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1393.0',
#   'fat_100g': '3.33',
#   'carbohydrates_100g': '71.11',
#   'sugars_100g': '',
#   'proteins_100g': '13.33'},
#  {'product_name': 'Organic Oat Bran',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '29.0 g',
#   'energy_100g': '1661.0',
#   'fat_100g': '6.9',
#   'carbohydrates_100g': '68.97',
#   'sugars_100g': '',
#   'proteins_100g': '20.69'},
#  {'product_name': 'Organic Thick Cut Rolled Oats',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '26.0 g',
#   'energy_100g': '1527.0',
#   'fat_100g': '7.69',
#   'carbohydrates_100g': '61.54',
#   'sugars_100g': '',
#   'proteins_100g': '15.38'},
#  {'product_name': 'Organic Regular Rolled Oats',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '26.0 g',
#   'energy_100g': '1527.0',
#   'fat_100g': '7.69',
#   'carbohydrates_100g': '38.46',
#   'sugars_100g': '',
#   'proteins_100g': '15.38'},
#  {'product_name': 'Organic Rolled Rye Flakes',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '25.0 g',
#   'energy_100g': '1674.0',
#   'fat_100g': '2.0',
#   'carbohydrates_100g': '84.0',
#   'sugars_100g': '',
#   'proteins_100g': '16.0'},
#  {'product_name': 'Organic Steel-Cut Oats',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '1778.0',
#   'fat_100g': '7.5',
#   'carbohydrates_100g': '72.5',
#   'sugars_100g': '',
#   'proteins_100g': '17.5'},
#  {'product_name': 'Organic Spelt Berries',
#   'brands': 'Vitaspelt',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '46.0 g',
#   'energy_100g': '1184.0',
#   'fat_100g': '2.17',
#   'carbohydrates_100g': '69.57',
#   'sugars_100g': '',
#   'proteins_100g': '15.22'},
#  {'product_name': 'Organic Quick Rolled Oats',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '20.0 g',
#   'energy_100g': '1883.0',
#   'fat_100g': '7.5',
#   'carbohydrates_100g': '75.0',
#   'sugars_100g': '2.5',
#   'proteins_100g': '17.5'},
#  {'product_name': 'Countrywild Rice Blend',
#   'brands': 'Lundberg',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1393.0',
#   'fat_100g': '3.33',
#   'carbohydrates_100g': '77.78',
#   'sugars_100g': '',
#   'proteins_100g': '6.67'},
#  {'product_name': 'Organic Arboria Rice',
#   'brands': 'Lundberg',
#   'created_date': '2017-03-10',
#   'last_modified_date': '2017-03-10',
#   'serving_size': '45.0 g',
#   'energy_100g': '1490.0',
#   'fat_100g': '2.22',
#   'carbohydrates_100g': '95.56',
#   'sugars_100g': '',
#   'proteins_100g': '13.33'},
#  {'product_name': 'Lundberg Organic Golden Rose Medium Brown Rice',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '51.0 g',
#   'energy_100g': '1314.0',
#   'fat_100g': '1.96',
#   'carbohydrates_100g': '66.67',
#   'sugars_100g': '',
#   'proteins_100g': '5.88'},
#  {'product_name': 'Lundberg Olde World Pilaf',
#   'brands': 'Pcc Farmland Trust',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1423.0',
#   'fat_100g': '3.33',
#   'carbohydrates_100g': '73.33',
#   'sugars_100g': '2.22',
#   'proteins_100g': '11.11'},
#  {'product_name': 'Pack de 2 Twix',
#   'brands': 'Twix, Lundberg',
#   'created_date': '2015-01-01',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '48.0 g',
#   'energy_100g': '1481.0',
#   'fat_100g': '4.17',
#   'carbohydrates_100g': '77.08',
#   'sugars_100g': '',
#   'proteins_100g': '6.25'},
#  {'product_name': 'Organic Short Grain Brown Rice',
#   'brands': 'Lundberg',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '51.0 g',
#   'energy_100g': '1393.0',
#   'fat_100g': '2.94',
#   'carbohydrates_100g': '78.43',
#   'sugars_100g': '',
#   'proteins_100g': '5.88'},
#  {'product_name': 'Organic Sweet Brown Rice',
#   'brands': 'Lundberg',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '51.0 g',
#   'energy_100g': '1477.0',
#   'fat_100g': '0.98',
#   'carbohydrates_100g': '78.43',
#   'sugars_100g': '',
#   'proteins_100g': '7.84'},
#  {'product_name': 'Organic California White Sushi Rice',
#   'brands': 'Lundberg',
#   'created_date': '2017-03-10',
#   'last_modified_date': '2017-03-10',
#   'serving_size': '45.0 g',
#   'energy_100g': '1490.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '80.0',
#   'sugars_100g': '',
#   'proteins_100g': '6.67'},
#  {'product_name': 'Organic Harvest Pilaf',
#   'brands': 'Sunridge',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '45.0 g',
#   'energy_100g': '1674.0',
#   'fat_100g': '2.22',
#   'carbohydrates_100g': '71.11',
#   'sugars_100g': '2.22',
#   'proteins_100g': '15.56'},
#  {'product_name': 'Organic Wild Rice',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '75.0 g',
#   'energy_100g': '1452.0',
#   'fat_100g': '12.0',
#   'carbohydrates_100g': '72.0',
#   'sugars_100g': '',
#   'proteins_100g': '12.0'},
#  {'product_name': 'Organic Flax Seed',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2092.0',
#   'fat_100g': '35.71',
#   'carbohydrates_100g': '39.29',
#   'sugars_100g': '',
#   'proteins_100g': '17.86'},
#  {'product_name': 'Cranberries',
#   'brands': 'Torn & Glasser',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '1255.0',
#   'fat_100g': '0.0',
#   'carbohydrates_100g': '83.33',
#   'sugars_100g': '66.67',
#   'proteins_100g': '0.0'},
#  {'product_name': 'Turkish Apricots',
#   'brands': 'Northgate',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '1046.0',
#   'fat_100g': '0.0',
#   'carbohydrates_100g': '62.5',
#   'sugars_100g': '52.5',
#   'proteins_100g': '2.5'},
#  {'product_name': 'Banana Chips Sweetened',
#   'brands': 'Not A Branded Item',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2243.0',
#   'fat_100g': '28.57',
#   'carbohydrates_100g': '64.29',
#   'sugars_100g': '14.29',
#   'proteins_100g': '3.57'},
#  {'product_name': 'Granola Honey Almonds',
#   'brands': 'Northgate',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '55.0 g',
#   'energy_100g': '1674.0',
#   'fat_100g': '14.55',
#   'carbohydrates_100g': '60.0',
#   'sugars_100g': '21.82',
#   'proteins_100g': '9.09'},
#  {'product_name': 'Chili Mango',
#   'brands': 'Torn & Glasses',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '1569.0',
#   'fat_100g': '2.5',
#   'carbohydrates_100g': '87.5',
#   'sugars_100g': '65.0',
#   'proteins_100g': '2.5'},
#  {'product_name': 'Milk Chocolate Pretzels',
#   'brands': 'Torn & Glasser',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '1883.0',
#   'fat_100g': '22.5',
#   'carbohydrates_100g': '70.0',
#   'sugars_100g': '42.5',
#   'proteins_100g': '5.0'},
#  {'product_name': 'Peanuts',
#   'brands': 'Northgate',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '1941.0',
#   'fat_100g': '17.86',
#   'carbohydrates_100g': '60.71',
#   'sugars_100g': '17.86',
#   'proteins_100g': '17.86'},
#  {'product_name': 'Organic Salted Pistachios',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2540.0',
#   'fat_100g': '46.43',
#   'carbohydrates_100g': '32.14',
#   'sugars_100g': '10.71',
#   'proteins_100g': '21.43'},
#  {'product_name': 'Organic Dried Turkish Apricots, Bin # 5801',
#   'brands': 'Coombs Family',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '941.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '55.0',
#   'sugars_100g': '47.5',
#   'proteins_100g': '2.5'},
#  {'product_name': 'Organic Unsalted Pistachios',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2540.0',
#   'fat_100g': '46.43',
#   'carbohydrates_100g': '32.14',
#   'sugars_100g': '10.71',
#   'proteins_100g': '21.43'},
#  {'product_name': 'Organic Medjool Dates',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '100.0 g',
#   'energy_100g': '1218.0',
#   'fat_100g': '0.1',
#   'carbohydrates_100g': '70.4',
#   'sugars_100g': '65.7',
#   'proteins_100g': '2.2'},
#  {'product_name': 'Organic Pitted Prunes',
#   'brands': 'Pcc',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '1464.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '90.0',
#   'sugars_100g': '62.5',
#   'proteins_100g': '2.5'},
#  {'product_name': 'Organic Pitted Deglet Dates',
#   'brands': 'Kid Picks',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '1255.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '75.0',
#   'sugars_100g': '62.5',
#   'proteins_100g': '2.5'},
#  {'product_name': 'Sweetened Dried Cranberries',
#   'brands': 'Kid Picks',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '1255.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '72.5',
#   'sugars_100g': '65.0',
#   'proteins_100g': '2.5'},
#  {'product_name': 'Organic Zante Currants',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '1046.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '65.0',
#   'sugars_100g': '62.5',
#   'proteins_100g': '3.75'},
#  {'product_name': 'Organic Thompson Raisins',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '1360.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '75.0',
#   'sugars_100g': '70.0',
#   'proteins_100g': '2.5'},
#  {'product_name': 'Organic Unrefined Extra Virgin Coconut Oil',
#   'brands': 'Aunt Patty',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '14.0 g',
#   'energy_100g': '3586.0',
#   'fat_100g': '100.0',
#   'carbohydrates_100g': '',
#   'sugars_100g': '',
#   'proteins_100g': ''},
#  {'product_name': 'Organic Brown Basmati Rice',
#   'brands': 'Lundberg',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '49.0 g',
#   'energy_100g': '1452.0',
#   'fat_100g': '4.08',
#   'carbohydrates_100g': '77.55',
#   'sugars_100g': '',
#   'proteins_100g': '8.16'},
#  {'product_name': 'Organic White Basmati Rice',
#   'brands': 'Lundberg',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '50.0 g',
#   'energy_100g': '1506.0',
#   'fat_100g': '1.0',
#   'carbohydrates_100g': '82.0',
#   'sugars_100g': '',
#   'proteins_100g': '8.0'},
#  {'product_name': 'Organic Unrefined Mascobado Sugar',
#   'brands': 'Alter Eco',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '4.0 g',
#   'energy_100g': '1569.0',
#   'fat_100g': '',
#   'carbohydrates_100g': '100.0',
#   'sugars_100g': '100.0',
#   'proteins_100g': ''},
#  {'product_name': 'Organic U.S. Peanuts',
#   'brands': "Cb's Nuts",
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '37.0 g',
#   'energy_100g': '2377.0',
#   'fat_100g': '48.65',
#   'carbohydrates_100g': '21.62',
#   'sugars_100g': '4.05',
#   'proteins_100g': '24.32'},
#  {'product_name': 'Almonds',
#   'brands': 'Equal Exchange',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '50.0',
#   'carbohydrates_100g': '20.0',
#   'sugars_100g': '3.33',
#   'proteins_100g': '20.0'},
#  {'product_name': 'Pecan Halves',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.4 g',
#   'energy_100g': '2946.0',
#   'fat_100g': '70.42',
#   'carbohydrates_100g': '14.08',
#   'sugars_100g': '7.04',
#   'proteins_100g': '7.04'},
#  {'product_name': 'Organic Whole Cashews',
#   'brands': 'Equal Exchange',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '34.0 g',
#   'energy_100g': '2402.0',
#   'fat_100g': '47.06',
#   'carbohydrates_100g': '32.35',
#   'sugars_100g': '5.88',
#   'proteins_100g': '14.71'},
#  {'product_name': 'Organic Pearl Quinoa',
#   'brands': 'Unfi',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '1778.0',
#   'fat_100g': '6.25',
#   'carbohydrates_100g': '75.0',
#   'sugars_100g': '',
#   'proteins_100g': '17.5'},
#  {'product_name': 'Fresh Organic Carrots',
#   'brands': 'Bunny-Luv',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '78.0 g',
#   'energy_100g': '159.0',
#   'fat_100g': '0.0',
#   'carbohydrates_100g': '8.97',
#   'sugars_100g': '6.41',
# ...
#   'serving_size': '38.0 g',
#   'energy_100g': '2531.0',
#   'fat_100g': '42.11',
#   'carbohydrates_100g': '47.37',
#   'sugars_100g': '39.47',
#   'proteins_100g': '7.89'},
#  {'product_name': 'Rocher, Fine Hazelnut Chocolates',
#   'brands': 'Ferrero,  Ferrero Rocher',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '38.0 g',
#   'energy_100g': '2531.0',
#   'fat_100g': '42.11',
#   'carbohydrates_100g': '47.37',
#   'sugars_100g': '39.47',
#   'proteins_100g': '7.89'},
#  {'product_name': 'Rocher, Fine Hazelnut Chocolates',
#   'brands': 'Ferrero,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '38.0 g',
#   'energy_100g': '2531.0',
#   'fat_100g': '42.11',
#   'carbohydrates_100g': '47.37',
#   'sugars_100g': '39.47',
#   'proteins_100g': '7.89'},
#  {'product_name': 'Rocher, Hazelnut Chocolates',
#   'brands': 'Ferrero,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '38.0 g',
#   'energy_100g': '2531.0',
#   'fat_100g': '42.11',
#   'carbohydrates_100g': '47.37',
#   'sugars_100g': '39.47',
#   'proteins_100g': '7.89'},
#  {'product_name': 'Rocher, Fine Hazelnut Chocolates',
#   'brands': 'Ferrero,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '38.0 g',
#   'energy_100g': '2531.0',
#   'fat_100g': '42.11',
#   'carbohydrates_100g': '47.37',
#   'sugars_100g': '39.47',
#   'proteins_100g': '7.89'},
#  {'product_name': 'Fine Hazelnut Chocolates',
#   'brands': 'Ferrero',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '38.0 g',
#   'energy_100g': '2423.0',
#   'fat_100g': '42.11',
#   'carbohydrates_100g': '44.74',
#   'sugars_100g': '39.47',
#   'proteins_100g': '7.89'},
#  {'product_name': 'Rocher',
#   'brands': 'Ferrero',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '38.0 g',
#   'energy_100g': '2531.0',
#   'fat_100g': '42.11',
#   'carbohydrates_100g': '47.37',
#   'sugars_100g': '39.47',
#   'proteins_100g': '7.89'},
#  {'product_name': 'Raffaello, Almond Coconut Treat',
#   'brands': 'Confetteria',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2648.0',
#   'fat_100g': '50.0',
#   'carbohydrates_100g': '43.33',
#   'sugars_100g': '33.33',
#   'proteins_100g': '6.67'},
#  {'product_name': 'Raffaello, Almond Coconut Treat',
#   'brands': 'Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2648.0',
#   'fat_100g': '50.0',
#   'carbohydrates_100g': '40.0',
#   'sugars_100g': '33.33',
#   'proteins_100g': '6.67'},
#  {'product_name': 'Fine Assorted Confection Chocolates',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '37.5',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '37.5',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '40.0',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '40.0',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '40.0',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '40.0',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '40.0',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '40.0',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '40.0',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Congections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '40.0',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '37.5',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '37.5',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '37.5',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '37.5',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '37.5',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Collections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '37.5',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Conefections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '37.5',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '40.0',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fine Assorted Confections',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '40.0',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Fererro, Nutella, B-Ready Filled Wafer Bars',
#   'brands': 'Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '22.0 g',
#   'energy_100g': '2092.0',
#   'fat_100g': '27.27',
#   'carbohydrates_100g': '63.64',
#   'sugars_100g': '45.45',
#   'proteins_100g': '9.09'},
#  {'product_name': 'Fine Assorted Confection',
#   'brands': 'Ferrero Collection,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2510.0',
#   'fat_100g': '42.5',
#   'carbohydrates_100g': '47.5',
#   'sugars_100g': '40.0',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Eggs Chocolate Covered Crispy Eggs, Hazelnut',
#   'brands': 'Ferrero,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2406.0',
#   'fat_100g': '37.5',
#   'carbohydrates_100g': '52.5',
#   'sugars_100g': '45.0',
#   'proteins_100g': '7.5'},
#  {'product_name': 'Eggs Chocolate Covered Crispy Eggs, Cocoa',
#   'brands': 'Ferrero,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '40.0 g',
#   'energy_100g': '2301.0',
#   'fat_100g': '37.5',
#   'carbohydrates_100g': '52.5',
#   'sugars_100g': '42.5',
#   'proteins_100g': '5.0'},
#  {'product_name': 'Hazelnut Spread + Breadsticks',
#   'brands': 'Nutella',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '52.0 g',
#   'energy_100g': '2171.0',
#   'fat_100g': '25.0',
#   'carbohydrates_100g': '63.46',
#   'sugars_100g': '44.23',
#   'proteins_100g': '7.69'},
#  {'product_name': 'Hazelnut Spread + Breadsticks',
#   'brands': 'Nutella',
#   'created_date': '2016-03-11',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '52.0 g',
#   'energy_100g': '2171.0',
#   'fat_100g': '26.92',
#   'carbohydrates_100g': '65.38',
#   'sugars_100g': '44.23',
#   'proteins_100g': '7.69'},
#  {'product_name': 'Hazelnut Spread + Pretzel Sticks',
#   'brands': 'Nutella',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '54.0 g',
#   'energy_100g': '2092.0',
#   'fat_100g': '24.07',
#   'carbohydrates_100g': '66.67',
#   'sugars_100g': '42.59',
#   'proteins_100g': '7.41'},
#  {'product_name': '12 Pack Hazelnut Spread + Breadsticks',
#   'brands': 'Nutella Ferrero',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '52.0 g',
#   'energy_100g': '2171.0',
#   'fat_100g': '26.92',
#   'carbohydrates_100g': '65.38',
#   'sugars_100g': '44.23',
#   'proteins_100g': '7.69'},
#  {'product_name': 'Nutella, Hazelnut Spread With Cocoa',
#   'brands': 'Ferrero,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '37.0 g',
#   'energy_100g': '2264.0',
#   'fat_100g': '32.43',
#   'carbohydrates_100g': '62.16',
#   'sugars_100g': '56.76',
#   'proteins_100g': '5.41'},
#  {'product_name': 'Nutella, Hazelnut Spread With Cocoa',
#   'brands': 'Ferrero,  Ferrero U.S.A.  Incorporated',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '37.0 g',
#   'energy_100g': '2264.0',
#   'fat_100g': '32.43',
#   'carbohydrates_100g': '62.16',
#   'sugars_100g': '56.76',
#   'proteins_100g': '5.41'},
#  {'product_name': 'Nutella',
#   'brands': 'Ferrero,Nutella',
#   'created_date': '2013-07-02',
#   'last_modified_date': '2017-01-12',
#   'serving_size': '37.0 g',
#   'energy_100g': '2260.0',
#   'fat_100g': '32.4',
#   'carbohydrates_100g': '56.8',
#   'sugars_100g': '56.8',
#   'proteins_100g': '5.41'},
#  {'product_name': 'Mountain Pure, Coconut Chips',
#   'brands': 'Truicoco',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '20.0 g',
#   'energy_100g': '2406.0',
#   'fat_100g': '35.0',
#   'carbohydrates_100g': '60.0',
#   'sugars_100g': '40.0',
#   'proteins_100g': '5.0'},
#  {'product_name': 'Chicken Noodle Soup',
#   'brands': "Trader Joe's",
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '248.0 g',
#   'energy_100g': '151.0',
#   'fat_100g': '0.4',
#   'carbohydrates_100g': '5.65',
#   'sugars_100g': '0.4',
#   'proteins_100g': '2.42'},
#  {'product_name': 'Spaghetti Sauce, Roasted Garlic',
#   'brands': "Trader Giotto's",
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '125.0 g',
#   'energy_100g': '234.0',
#   'fat_100g': '2.0',
#   'carbohydrates_100g': '8.0',
#   'sugars_100g': '4.8',
#   'proteins_100g': '1.6'},
#  {'product_name': 'Mushroom & Herb Risotto',
#   'brands': "Trader Joe's",
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '42.0 g',
#   'energy_100g': '1494.0',
#   'fat_100g': '0.0',
#   'carbohydrates_100g': '78.57',
#   'sugars_100g': '2.38',
#   'proteins_100g': '7.14'},
#  {'product_name': 'Apricot Butter',
#   'brands': 'House Of Webster',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '17.0 g',
#   'energy_100g': '615.0',
#   'fat_100g': '0.0',
#   'carbohydrates_100g': '41.18',
#   'sugars_100g': '23.53',
#   'proteins_100g': '0.0'},
#  {'product_name': 'Hu, Crunchy Chocolate Bar, Banana',
#   'brands': 'B R Group Inc.',
#   'created_date': '2017-03-10',
#   'last_modified_date': '2017-03-10',
#   'serving_size': '30.0 g',
#   'energy_100g': '1954.0',
#   'fat_100g': '40.0',
#   'carbohydrates_100g': '40.0',
#   'sugars_100g': '26.67',
#   'proteins_100g': '10.0'},
#  {'product_name': 'Hu Simple Chocolate Bar',
#   'brands': 'B R Group Inc.',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2230.0',
#   'fat_100g': '43.33',
#   'carbohydrates_100g': '46.67',
#   'sugars_100g': '30.0',
#   'proteins_100g': '6.67'},
#  {'product_name': 'Get Back To Human, Crunchy Fig Chocolate Bar',
#   'brands': 'Hu',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2092.0',
#   'fat_100g': '40.0',
#   'carbohydrates_100g': '43.33',
#   'sugars_100g': '30.0',
#   'proteins_100g': '6.67'},
#  {'product_name': 'Get Back To Human, Chocolate Bar, Crunchy Mint',
#   'brands': 'Hu',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2230.0',
#   'fat_100g': '43.33',
#   'carbohydrates_100g': '43.33',
#   'sugars_100g': '26.67',
#   'proteins_100g': '6.67'},
#  {'product_name': 'Get Back To Human, Chocolate Bar, Almond Butter + Puffed Quinoa',
#   'brands': 'Hu',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '30.0 g',
#   'energy_100g': '2372.0',
#   'fat_100g': '50.0',
#   'carbohydrates_100g': '40.0',
#   'sugars_100g': '26.67',
#   'proteins_100g': '6.67'},
#  ...]

# %%
len(products)
# Out:
# 150490

# %%
# Other way
products_file = open(csv_file_path)
products = list(csv.DictReader(products_file))
products_file.close()

# %%
# Now look at the first 3 entries
products[0:3]
# Out:
# [{'product_name': 'Banana Chips Sweetened (Whole)',
#   'brands': '',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2243.0',
#   'fat_100g': '28.57',
#   'carbohydrates_100g': '64.29',
#   'sugars_100g': '14.29',
#   'proteins_100g': '3.57'},
#  {'product_name': 'Peanuts',
#   'brands': 'Torn & Glasser',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '1941.0',
#   'fat_100g': '17.86',
#   'carbohydrates_100g': '60.71',
#   'sugars_100g': '17.86',
#   'proteins_100g': '17.86'},
#  {'product_name': 'Organic Salted Nut Mix',
#   'brands': 'Grizzlies',
#   'created_date': '2017-03-09',
#   'last_modified_date': '2017-03-09',
#   'serving_size': '28.0 g',
#   'energy_100g': '2540.0',
#   'fat_100g': '57.14',
#   'carbohydrates_100g': '17.86',
#   'sugars_100g': '3.57',
#   'proteins_100g': '17.86'}]

# %% [markdown]
# # Data Preparation

# %% [markdown]
# Now that we've gotten all of our data into a Python object, we can prepare it for analysis. Let's look at a sample observation and consider how we might want to process it to make it easier to analyze.

# %%
products[0]
# Out:
# {'product_name': 'Banana Chips Sweetened (Whole)',
#  'brands': '',
#  'created_date': '2017-03-09',
#  'last_modified_date': '2017-03-09',
#  'serving_size': '28.0 g',
#  'energy_100g': '2243.0',
#  'fat_100g': '28.57',
#  'carbohydrates_100g': '64.29',
#  'sugars_100g': '14.29',
#  'proteins_100g': '3.57'}

# %% [markdown]
# **Discussion:** How might you clean these entries to make them easier to analyze?
#
# - missing info for brand (blank)
# - numbers are not numbers (they are currently strings)
# - some have units some don't
# - date formats, different decimals
# - date is a string (we could maybe index to grab year or month or day)

# %% [markdown]
# ## Clean the Serving Size (and other numbers)

# %% [markdown]
# You might have noticed that all of these numbers are strings! Hard to do things like math on strings.
#
# In addition, the `serving_size` here has ` g` at the end - in fact, I know from doing more analysis on this data that ALL of these are in grams, and have ` g` at the end. Let's remove that so we can treat those as numbers too!

# %%
products[0]['sugars_100g']
# Out:
# '14.29'

# %%
# First, let's do a one off example - how to we turn a string into a float?
float(products[0]['sugars_100g'])
# Out:
# 14.29

# %%
type(float(products[0]['sugars_100g']))
# Out:
# float

# %%
float(products[0]['serving_size'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-336164107619> in <module>
# ----> 1 float(products[0]['serving_size'])
#
# ValueError: could not convert string to float: '28.0 g'

# %%
products[0]['serving_size'].strip(" g")
# Out:
# '28.0'

# %%
# And how can we remove the ' g' from the end of the serving sizes?
float(products[0]['serving_size'].strip(" g"))
# Out:
# 28.0

# %%
# Now that we've figured out what to do, let's clean up these dicts!
for product in products:
    # clean up serving size
    product['serving_size_g'] = float(product['serving_size'].strip(" g"))
    # clean up values of our 100g keys
    for key, value in product.items():
        if '100g' in key:
            #product[key] = float(value)
            # Wont work normally b/c we have blank values ""
            # Need to use try and except
            try: #tries to do this first
               product[key] = float(value)
            except: #will do this if the try threw an error
               product[key] = 0.0

# %%
# Check it out:
products[0]
# Out:
# {'product_name': 'Banana Chips Sweetened (Whole)',
#  'brands': '',
#  'created_date': '2017-03-09',
#  'last_modified_date': '2017-03-09',
#  'serving_size': '28.0 g',
#  'energy_100g': 2243.0,
#  'fat_100g': 28.57,
#  'carbohydrates_100g': 64.29,
#  'sugars_100g': 14.29,
#  'proteins_100g': 3.57,
#  'serving_size_g': 28.0}

# %%
type(products[0]['proteins_100g'])
# Out:
# float

# %%
products[123]
# Out:
# {'product_name': 'Organic Arboria Rice',
#  'brands': 'Lundberg',
#  'created_date': '2017-03-10',
#  'last_modified_date': '2017-03-10',
#  'serving_size': '45.0 g',
#  'energy_100g': 1490.0,
#  'fat_100g': 2.22,
#  'carbohydrates_100g': 95.56,
#  'sugars_100g': 0.0,
#  'proteins_100g': 13.33,
#  'serving_size_g': 45.0}

# %% [markdown]
# ## Clean the Dates

# %% [markdown]
# Next we'll clean the dates so that we can easily get the month and year when each food was added to this database.

# %% [markdown]
# ### Using Python built-in methods

# %% [markdown]
# **Activity**: Process the `products` list to add numeric values for the month and year when each entry was first created! (aka parse out `created_date`)

# %%
products[0]['created_date']
# Out:
# '2017-03-09'

# %%
products[0]['created_date'][0:4]
# Out:
# '2017'

# %%
int(products[0]['created_date'][0:4])
# Out:
# 2017

# %%
int(products[0]['created_date'][5:7])
# Out:
# 3

# %%
products[0]['created_date'][5:7]
# Out:
# '03'

# %%
for product in products:
    str_date = product['created_date']
    year = int(str_date[0:4])
    month = int(str_date[5:7])
    product['month'] = month
    product['year'] = year

# %% [markdown]
# <details>
#     <summary><b><u>Click Here for Answer Code</u></b></summary>
#
# ```python
# for product in products[:10]:
#     # Save the date to a variable
#     string_date = product["created_date"]
#
#     # Extract the sale year and month from the string, and cast to int
#     created_year = int(string_date[0:4])
#     created_month = int(string_date[5:7])
#
#     # Add the sale year and month to each dictionary element of sales
#     product["created_year"] = created_year
#     product["created_month"] = created_month
# ```
# </details>

# %%
products[4000]
# Out:
# {'product_name': 'Baby Spinach',
#  'brands': 'Fresh Selections',
#  'created_date': '2017-03-09',
#  'last_modified_date': '2017-03-09',
#  'serving_size': '85.0 g',
#  'energy_100g': 100.0,
#  'fat_100g': 0.0,
#  'carbohydrates_100g': 3.53,
#  'sugars_100g': 0.0,
#  'proteins_100g': 2.35,
#  'serving_size_g': 85.0,
#  'month': 3,
#  'year': 2017}

# %%
for product in products:
    product['month'] = int(product['created_date'][5:7])

# %%
products[1]
# Out:
# {'product_name': 'Peanuts',
#  'brands': 'Torn & Glasser',
#  'created_date': '2017-03-09',
#  'last_modified_date': '2017-03-09',
#  'serving_size': '28.0 g',
#  'energy_100g': 1941.0,
#  'fat_100g': 17.86,
#  'carbohydrates_100g': 60.71,
#  'sugars_100g': 17.86,
#  'proteins_100g': 17.86,
#  'serving_size_g': 28.0,
#  'month': 3,
#  'year': 2017}

# %% [markdown]
# # Data Analysis

# %% [markdown]
# Now that you have a cleaner version of the data, we can finally start to perform some data analysis.

# %% [markdown]
# ## Question 1: What is the range of years for which we have data?

# %%
import numpy as np

# %%
# Your work here
years = set([product['year'] for product in products])
years
# Out:
# {2012, 2013, 2014, 2015, 2016, 2017}

# %%
min(years), max(years)
# Out:
# (2012, 2017)

# %%
# sets have access to unique methods (intersection, union, etc...)
years.

# %% [markdown]
# <details>
#             <summary><b><u>Answer</u></b></summary>
#
# ```python
# years = [product['created_year'] for product in products]
# print(min(years))
# print(max(years))
# ```
# </details>

# %% [markdown]
# ## Question 2: What is the average number of calories per 100g for all of these foods?

# %%
products[0]

# %%
# Your work here
cals = [(product['product_name'], product['energy_100g']) for product in products]
cals
# Out:
# [('Banana Chips Sweetened (Whole)', 2243.0),
#  ('Peanuts', 1941.0),
#  ('Organic Salted Nut Mix', 2540.0),
#  ('Organic Polenta', 1552.0),
#  ('Breadshop Honey Gone Nuts Granola', 1933.0),
#  ('Organic Long Grain White Rice', 1490.0),
#  ('Organic Muesli', 1833.0),
#  ('Organic Dark Chocolate Minis', 2406.0),
#  ('Organic Sunflower Oil', 3586.0),
#  ('Organic Adzuki Beans', 1393.0),
#  ('Organic Penne Pasta', 1540.0),
#  ('Zen Party Mix', 2230.0),
#  ('Organic Golden Flax Seeds', 2590.0),
#  ('Organic Spicy Punks', 2536.0),
#  ('Cinnamon Nut Granola', 1824.0),
#  ('Organic Hazelnuts', 2632.0),
#  ('Organic Sweetened Banana Chips', 2092.0),
#  ('Lotus Organic Brown Jasmine Rice', 1582.0),
#  ('Organic Oat Groats', 1096.0),
#  ('Energy Power Mix', 1464.0),
#  ('Antioxidant Mix - Berries & Chocolate', 2092.0),
#  ('Organic Quinoa Coconut Granola With Mango', 1674.0),
#  ('Fire Roasted Hatch Green Chile Almonds', 2372.0),
#  ('Peanut Butter Power Chews', 1954.0),
#  ('Real Salt Granular', 0.0),
#  ('Organic Unswt Berry Coconut Granola', 1548.0),
#  ('Roasted Salted Black Pepper Cashews', 2372.0),
#  ('Thai Curry Roasted Cashews', 2372.0),
#  ('Wasabi Tamari Almonds', 2230.0),
#  ('Organic Medium Shredded Coconut', 2230.0),
#  ('Organic Red Quinoa', 1490.0),
#  ('Dark Chocolate Coconut Chews', 2092.0),
#  ('Seventh Heaven Organic Trail Mix', 2092.0),
#  ('Organic Unsweetened Granola, Cinnamon Almond', 1887.0),
#  ('Organic Blueberry Almond Granola', 1674.0),
#  ('Sweeteners, Demerara Turbinado Sugar', 1569.0),
#  ("Aunt Maple's Crunchy Granola", 2092.0),
#  ('Organic Coconut Chips', 2761.0),
#  ('Organic Black Beans', 1393.0),
#  ('Organic Whole Grain Emmer Farro', 1515.0),
#  ('Organic Hard Red Wheat Berries', 1335.0),
#  ("Aunt Ginger's Snappy Granola", 1941.0),
#  ('Dark Chocolate Sea Salt & Turbinado Almonds', 2197.0),
#  ('Divinely Organic Granola', 1749.0),
#  ('Organic Black Chia Seeds', 2046.0),
#  ('Organic French Green Lentils', 1490.0),
#  ('Organic Garbanzo Beans', 1335.0),
#  ('Organic Green Split Peas', 1582.0),
#  ('Organic Small Red Chili Beans', 699.0),
#  ('Organic Small White Beans', 1674.0),
#  ('Organic Grey-Green Lentils', 1582.0),
#  ('Organic Yellow Split Peas', 1582.0),
#  ('Organic Mung Beans', 1477.0),
#  ('Organic Baby Lima Beans', 1393.0),
#  ('Organic Dark Red Kidney Bean', 1272.0),
#  ('Coconut Almond Granola', 2054.0),
#  ('Super Nutty Granola', 1904.0),
#  ('Maple Almond Granola', 1904.0),
#  ('35% Fruit And Fiber Muesli', 1523.0),
#  ('Rebel Crunch Granola', 1720.0),
#  ('Organic Mixed Vegetable Spirals', 1490.0),
#  ('Tricolor Tortellini', 1611.0),
#  ('Organic Couscous', 1582.0),
#  ('Organic Spaghetti', 1569.0),
#  ('Orzo Rosa Marina', 1443.0),
#  ('Organic Refined Spelt Flour', 1393.0),
#  ('10-Grain Pancake Mix', 1297.0),
#  ('Fine Sea Salt', 0.0),
#  ('Sweeteners, Organic Fair Trade Sugar', 1569.0),
#  ('Organic Refined Unbleached White Flour', 1536.0),
#  ('Organic Whole Brown Rice Flour', 1891.0),
#  ('Organic Whole Spelt Flour', 1356.0),
#  ('Organic Whole Rye Flour', 1393.0),
#  ('Granola Cranberry And Acai', 1824.0),
#  ('Organic Medium Whole Wheat Flour', 1552.0),
#  ('Organic Soft Whole Wheat Pastry Flour', 1644.0),
#  ('Peanuts, Mixed Nuts', 2389.0),
#  ('Organic Large Raw Whole Cashews', 2648.0),
#  ('Organic Brown Sesame Seeds', 2439.0),
#  ('Organic White Sesame Seeds', 2439.0),
#  ('Almonds Hickory-Smoked', 2690.0),
#  ('Foods, Spanish Peanuts', 2389.0),
#  ('Foods, Honey Roasted Nut Mix', 2389.0),
#  ('Roasted Salted Sunflower Seeds', 2766.0),
#  ('Foods, Deluxe Nut Mix', 2540.0),
#  ('Foods, Honey Roast Nuts & Fruit Mix', 2176.0),
#  ('Organic Raw Walnuts', 2678.0),
#  ('Organic Raw Sunflower Seeds', 2218.0),
#  ('Organic Trail Mix', 1812.0),
#  ('Organic Pecan Halves', 2946.0),
#  ('Unsalted Dry Roasted Almonds', 2791.0),
#  ('Organic Raw Pumpkin Seeds', 2510.0),
#  ('Curry Lentil Soup Mix', 1289.0),
#  ('Split Pea Soup Mix', 1314.0),
#  ("Whole Wheat 'N Honey Fig Bars", 1255.0),
#  ('Chocolate Nut Crunch', 1954.0),
#  ('Milk Chocolate Peanut Butter Malt Balls', 2197.0),
#  ('Organic Tamari Pumpkin Seed', 2092.0),
#  ('Yogurt Pretzels', 2092.0),
#  ('Organic Kamut Flakes', 941.0),
#  ('Regular Rolled Oats', 1611.0),
#  ('Quick Rolled Oats', 1611.0),
#  ('Organic Bulgur', 1464.0),
#  ('Organic Toasted Buckwheat Groats', 1427.0),
#  ('Organic Rolled Barley Flakes', 1197.0),
#  ('Multigrain Cereal Flakes', 1540.0),
#  ('8-Grain Wheat Free Cereal', 1569.0),
#  ('Swiss-Style Muesli', 1749.0),
#  ('Organic Hulless Barley', 1548.0),
#  ('Organic Millet', 1569.0),
#  ('Organic Popcorn', 1506.0),
#  ('Organic Soft White Wheat Berries', 1423.0),
#  ('Organic Pearled Barley', 1506.0),
#  ('Organic Wheat Bran', 837.0),
#  ('Organic Raw Buckwheat Groats', 1393.0),
#  ('Organic Oat Bran', 1661.0),
#  ('Organic Thick Cut Rolled Oats', 1527.0),
#  ('Organic Regular Rolled Oats', 1527.0),
#  ('Organic Rolled Rye Flakes', 1674.0),
#  ('Organic Steel-Cut Oats', 1778.0),
#  ('Organic Spelt Berries', 1184.0),
#  ('Organic Quick Rolled Oats', 1883.0),
#  ('Countrywild Rice Blend', 1393.0),
#  ('Organic Arboria Rice', 1490.0),
#  ('Lundberg Organic Golden Rose Medium Brown Rice', 1314.0),
#  ('Lundberg Olde World Pilaf', 1423.0),
#  ('Pack de 2 Twix', 1481.0),
#  ('Organic Short Grain Brown Rice', 1393.0),
#  ('Organic Sweet Brown Rice', 1477.0),
#  ('Organic California White Sushi Rice', 1490.0),
#  ('Organic Harvest Pilaf', 1674.0),
#  ('Organic Wild Rice', 1452.0),
#  ('Organic Flax Seed', 2092.0),
#  ('Cranberries', 1255.0),
#  ('Turkish Apricots', 1046.0),
#  ('Banana Chips Sweetened', 2243.0),
#  ('Granola Honey Almonds', 1674.0),
#  ('Chili Mango', 1569.0),
#  ('Milk Chocolate Pretzels', 1883.0),
#  ('Peanuts', 1941.0),
#  ('Organic Salted Pistachios', 2540.0),
#  ('Organic Dried Turkish Apricots, Bin # 5801', 941.0),
#  ('Organic Unsalted Pistachios', 2540.0),
#  ('Organic Medjool Dates', 1218.0),
#  ('Organic Pitted Prunes', 1464.0),
#  ('Organic Pitted Deglet Dates', 1255.0),
#  ('Sweetened Dried Cranberries', 1255.0),
#  ('Organic Zante Currants', 1046.0),
#  ('Organic Thompson Raisins', 1360.0),
#  ('Organic Unrefined Extra Virgin Coconut Oil', 3586.0),
#  ('Organic Brown Basmati Rice', 1452.0),
#  ('Organic White Basmati Rice', 1506.0),
#  ('Organic Unrefined Mascobado Sugar', 1569.0),
#  ('Organic U.S. Peanuts', 2377.0),
#  ('Almonds', 2510.0),
#  ('Pecan Halves', 2946.0),
#  ('Organic Whole Cashews', 2402.0),
#  ('Organic Pearl Quinoa', 1778.0),
#  ('Fresh Organic Carrots', 159.0),
#  ('Butter Croissants', 1523.0),
#  ('Wild Blueberry Muffins', 1548.0),
#  ('Bolillos', 1159.0),
#  ('Biscuit', 1452.0),
#  ('Biscuit', 1339.0),
#  ('Oatmeal Raisin Cookie', 1778.0),
#  ('Sliced Plain Bagel', 1527.0),
#  ('Scone', 1920.0),
#  ('Belgian Vanilla Waffle', 2067.0),
#  ('Seasonal Cookie Platter', 1866.0),
#  ('Muffin', 1749.0),
#  ('Muffin', 1477.0),
#  ('Freshly Baked Italian Loaf', 941.0),
#  ('Freshly Baked Apple Pie', 1155.0),
#  ('Snickerdoodle Cookies', 1866.0),
#  ('Freshly Baked In Store Cherry Turnover', 1674.0),
#  ('Apple Turnover', 1623.0),
#  ('Pineapple Coconut Muffins', 1665.0),
#  ('Assorted Strudel Bite', 1569.0),
#  ('Freshly Baked Chocolat Croissant', 1812.0),
#  ('Cornbread', 1632.0),
#  ('La Brea Bakery Ciabatta Loaf Freshly Baked In Store', 1176.0),
#  ('Belgian Choc Chip Waffle', 2117.0),
#  ('Chocolate Scone', 2912.0),
#  ('Chamomile Herbal Tea', 0.0),
#  ('Herbal Tea, Peppermint', 0.0),
#  ('Linden Flowers Tea', 0.0),
#  ('Herbal Tea, Hibiscus', 1117.0),
#  ('Apple & Cinnamon Tea', 0.0),
#  ('Green Tea', 0.0),
#  ('Shave Grass Herbal Tea', 0.0),
#  ('Herbal Tea, Chamomile * Mint', 0.0),
#  ('Artichoke Herbal Tea', 0.0),
#  ("Dieter's Herbal Tea", 0.0),
#  ('Kidneytea, Herbal Tea', 0.0),
#  ('Bronchtea', 0.0),
#  ('100% Pure Canola Oil', 3586.0),
#  ('Original Buttery Spread', 2690.0),
#  ('Buttery Spread, With Flaxseed Oil', 2389.0),
#  ('Lithuanian Rye Bread', 954.0),
#  ('Magic Stars Chocolates', 2330.0),
#  ('Magic Stars Chocolates', 2330.0),
#  ('Digestives Cheesecake, Lemon', 2130.0),
#  ('Mini Gingerbread Men, Milk Chocolate', 2013.0),
#  ('Organic Flourless Sprouted 7-Grain Bread', 983.0),
#  ('Puppodums', 1159.0),
#  ('Monterey Jack', 1494.0),
#  ('Bakers Best, White Bread', 983.0),
#  ('Bakers Best, Rye Bread', 1071.0),
#  ('Warner Hudson, Whisky Chocolates', 1879.0),
#  ('Piasten, Chocolate Assortment', 2029.0),
#  ("Sweet 'N' Hot Salad Peppers", 598.0),
#  ("Big Papa's, Southern Sauce", 1046.0),
#  ('Between!, Dental Gum, Natural Cool Mint', 837.0),
#  ('Eco-Dent, Between!, Sugar Free Dental Gum, Cinnamon', 837.0),
#  ('Knusperflakes Mit Knusprigen Cornflakes', 2209.0),
#  ('Rum Trauben Nuss, Milk Chocolate Wih Rum Raisins & Nuts', 2142.0),
#  ('Milk Chocolate With Caramelized Almonds', 2226.0),
#  ('Funsch, High Quality Marzipan', 1929.0),
#  ('Oatmeal Raisin Cookies', 1552.0),
#  ('The Best Peanut Butter Cookies', 1703.0),
#  ('Best Sweet-Potato Cookies', 1623.0),
#  ('Best Ginger Snap Cookies', 1623.0),
#  ('Ice Cream, Vanilla', 883.0),
#  ('Ice Cream, Butter Pecan', 1000.0),
#  ('Salted Sticks & Salted Pretzels', 1548.0),
#  ('Williams, Liquor Chocolate With Williams Pear', 1954.0),
#  ('Sea Salt Potato Chips', 2243.0),
#  ('Solid Milk Chocolate', 2318.0),
#  ('Madelaine Chocolate Company, Chocolate', 2301.0),
#  ('Milk Chocolate Rose', 2389.0),
#  ('Solid Dark Chocolate', 2197.0),
#  ('White Chocolate', 2406.0),
#  ('The Madelaine Chocolate Company, Solid Milk Chocolate Cigars', 2238.0),
#  ("Madelaine Chocolate, It's A Girl! Solid Milk Chocolate Cigars, Milk Chocolate",
#   2238.0),
#  ('The Madelaine Chocolate Company, All Natural Dark Chocolate Gift Stick',
#   2314.0),
#  ('The Madelaine Chocolate Company, Solid Milk Chocolate', 2301.0),
#  ('The Madelaine Chocolate Company, Solid Dark Chocolate', 2197.0),
#  ('Solid Milk Chocolate', 2326.0),
#  ('The Madelaine Chocolate Company, Solid Milk Chocolate', 2326.0),
#  ('The Madelaine Chocolate Comapny, Solid Milk Chocolate', 2314.0),
#  ('The Madelaine Chocolate Company, Solid Dark Chocolate', 2201.0),
#  ('Solid Dark Chocolate', 2201.0),
#  ('Milk Chocolate Malt Balls', 2197.0),
#  ('The Madelaine Chocolate Company, Solid Milk Chocolate', 2326.0),
#  ('The Madelaine Chocolate Company, Solid Dark Chocolate', 2209.0),
#  ('The Madelaine Chocolate Company, Solid Milk Chocolate Bunnies', 2272.0),
#  ('The Madelaine Chocolate Company, Solid Milk Chocolate Chicks', 2314.0),
#  ('Cornichons', 75.0),
#  ('Romaine Hearts', 75.0),
#  ('Romaine', 75.0),
#  ('Green Leaf Lettuce', 75.0),
#  ('Fresh Spinach', 100.0),
#  ('Cooking Spinach', 100.0),
#  ('Quick Cook Sprout Halves', 176.0),
#  ('Celery', 59.0),
#  ('Season & Steam Kalettes (Kale Sprouts)', 222.0),
#  ('Feletti, Pralines Candy, Milk Chocolate', 2209.0),
#  ('Feletti, Milk Chocolate Pralines', 2264.0),
#  ('Taami Elite, Milk Choolate Bar, Puffed Rice And Nougat-Caramel Cream',
#   2125.0),
#  ('Fruit Strip Snacks, Mango, Pineapple', 1343.0),
#  ('Fruit Twist Snacks Blueberry Pomec-Ranate', 1343.0),
#  ('Healthy Food Brands, A&W, Soda Bottles Gummy Candies With Real A&W Root Beer',
#   1046.0),
#  ('Emojeez, Gummies, Assorted Fruits', 1151.0),
#  ('Emojeez, Gummies Candy, Fruit', 1151.0),
#  ('Emojeez, Fruit Flavored Gummies, Green Apple, Orange, Fruit Punch, Lemon, Cherry Blue Raspberry',
#   1151.0),
#  ('Gummies', 1151.0),
#  ('Emojeez, Fruit Gummies, Assorted', 1151.0),
#  ('Emojeez, Gummies Candy, Fruit', 1151.0),
#  ('Lite, Fine Chocolate Candy Bar, Dark Chocolate', 1674.0),
#  ('Hfb Candy, Candy Crush Color Bombs', 1883.0),
#  ('Hfb Candy, Jelly Fish Candy', 1464.0),
#  ('Angry Birds, Fruit Snack, Cherry, Lemon, Raspberry, Apple, Grape, Strawberry',
#   1197.0),
#  ('Freeze-Dried Apple Slices', 1494.0),
#  ('Freeze-Dried Banana & Strawberry Slices', 1343.0),
#  ('Freeze-Dried Mango Slices', 1494.0),
#  ('Freeze-Dried Grapes', 1477.0),
#  ('Freeze-Dried Apple Slices', 1464.0),
#  ('Freeze-Dried Fruit Slices, Banana & Strawberry', 1464.0),
#  ('Freeze-Dried Mango Slices', 1464.0),
#  ('Freeze-Dried Grapes', 1569.0),
#  ('Wholesome & Delicious Dried Cranberries, Concord Grape', 1360.0),
#  ('Dried Cranberries, Pomegranate Flavor', 1360.0),
#  ('Dried Cranberries, Blueberry', 1360.0),
#  ('Dried Cranberries', 1360.0),
#  ('Dried Mediterranean Apricots', 941.0),
#  ('Dried Honey Crisp Apples', 1255.0),
#  ('Wholesome & Delicious Dried Mangos', 1464.0),
#  ('Triple Fruit Treat, Mango, Cranberries, Blueberries', 1456.0),
#  ('Red Apple Chips', 1594.0),
#  ('Pb&J Trail Mix, Grape', 1971.0),
#  ('Pb & J Trail Mix, Strawberry', 1971.0),
#  ('Pb&J Trail Mix, Grape', 1971.0),
#  ('Red Apple Chips', 1644.0),
#  ('Golden Apple Chips', 1644.0),
#  ('Green Apple Chips', 1644.0),
#  ('Fruit Gummies', 1255.0),
#  ('Fruit Gummies Candy', 1255.0),
#  ('Star Wars, Fruit Gummies', 1255.0),
#  ('Gummies', 1255.0),
#  ('Fruit Gummies', 1255.0),
#  ('Fruit Gummies', 1255.0),
#  ('Fruit Snacks, Cherry, Lemon, Raspberry, Apple, Grape, Strawberry', 1360.0),
#  ('Angry Birds, Fruit Snacks, Cherry-Lemon-Raspberry-Apple-Grape-Strawberry',
#   1293.0),
#  ('Fruit Ninja, Fruit Snacks, Original', 1255.0),
#  ('Fruit Snacks Red Belt', 1151.0),
#  ('Tnt Exploding Candy', 1393.0),
#  ('Exploding Candy', 1393.0),
#  ('Exploding Candy', 1393.0),
#  ('Bee, Creamed Honey With Raspberry, Raspberry', 1197.0),
#  ('Creamed Honey', 1197.0),
#  ('Bee, Creamed Honey With Cinnamon, Cinnamon', 1197.0),
#  ('Bee, Creamed Honey With Lemon', 1197.0),
#  ('Creamed Honey With Hibiscus', 1197.0),
#  ('Minis Creamed Honey With Cinnamon', 1255.0),
#  ('Creamed Honey With Lemon', 1255.0),
#  ('Creamed Honey With Raspberry', 1255.0),
#  ('Minis, Creamed Honey With Hibiscus', 1255.0),
#  ('Minis Candy', 1255.0),
#  ('Raw Shrimp', 247.0),
#  ('Yellow Corn Tortilla Chips', 1795.0),
#  ('Blueberry Pomegranate Crunch', 2243.0),
#  ('Pitted Prunes', 1046.0),
#  ('Augason Farms, Vital Wheat Gluten', 1393.0),
#  ('Caperberries In Vinegar', 75.0),
#  ('Hazelnut Spread + Breadsticks', 2171.0),
#  ('Hazelnut Spread With Cocoa', 2264.0),
#  ('La Eur, 3 Milk Soft Ripened Cheese', 1180.0),
#  ('Diced In Tomato Juice', 79.0),
#  ('Bambu Extra Cream Wafer Filled With Hazelnut Cream', 2159.0),
#  ('Strawberry Preserves', 1046.0),
#  ('Lumaconi Giant Pasta Shells Italian Macaroni Product', 1494.0),
#  ('Tofu Firm', 372.0),
#  ('Wild Rice', 1464.0),
#  ('Peanut Butter', 2485.0),
#  ('Peanut Butter', 2485.0),
#  ('Peanut Butter', 2485.0),
#  ("Traders Joe's, Baking Powder", 0.0),
#  ('Creamed Honey, Multi-Floral & Clover Blossoms', 1197.0),
#  ('mostly mesquite honey', 1200.0),
#  ('Salsa Autentica', 138.0),
#  ('First Crush, Unsweetened Gravenstein Apple Sauce', 172.0),
#  ('Whole Kernel Corn', 201.0),
#  ('Clam Chowder A Condensed Soup', 276.0),
#  ('Just Great Stuff, The Original Powdered Organic Peanut Butter', 1569.0),
#  ('Colossal Olives With Jalapeno Peppers', 347.0),
#  ('Marinara Sauce', 201.0),
#  ('Happy Cola Candy', 1406.0),
#  ('Finest Milk Chocolate', 2293.0),
#  ('International Inc., Frozen Shrimp Tempura', 983.0),
#  ('Tenero Alle Mandorle Limoncello Cookies', 1849.0),
#  ('Mediterranean Sea Salt', 0.0),
#  ('Fajitas Seasoning Mix', 1046.0),
#  ('Organic Sunny Days Snack Bars', 1540.0),
#  ('Chili Garlic Sauce', 0.0),
#  ('Sriracha Hot Chili Sauce', 418.0),
#  ('Wafers, Assortment Of Wafers', 2389.0),
#  ('French Onion Dip', 837.0),
#  ('Ventura, Soybean - Peanut Frying Oil Blend', 3586.0),
#  ('Assorted Pralines Chocolates', 1883.0),
#  ('Fancy Truffles', 2510.0),
#  ('Fancy Truffles, Hazelnut', 2615.0),
#  ('Fancy Truffles, Coffee', 2510.0),
#  ('Assorted Pralines', 1883.0),
#  ('Italian Style Grazioso Selection', 2218.0),
#  ('Finest Milk Chocolate', 2259.0),
#  ('Edelvollmilch- Chocolade Finest Milk Chocolate', 2259.0),
#  ('Edelvollmilch-Chocolade Finest Milk Chocolate', 2259.0),
#  ('Solid Milk Chocolate', 2301.0),
#  ('Mochi, Cashew-Date', 1021.0),
#  ('100% Grapefruit', 151.0),
#  ('Mit Aprikosen Fruchtfullung Lebkuchen Herzen', 1519.0),
#  ('Pfeffernusse Glazed Gingerbread Cookies', 1582.0),
#  ('Turkish Dried Apricots', 1255.0),
#  ('Extra Long Grain Enriched Rice', 1490.0),
#  ('Mousse, Milk Chocolate With Chocolate Mousse Filling', 2364.0),
#  ('Mousse, Milk Chocolate With Mousse Filling, Yogurt', 2389.0),
#  ('Funny Frisch, Chips Frisch, Peperoni', 2247.0),
#  ('Wild Alaskan Pink Salmon', 598.0),
#  ('Super Chunk, Peanut Butter Spread', 2485.0),
#  ('Creamy Peanut Butter', 2485.0),
#  ('Stuffed Queen Sevillano Olives', 448.0),
#  ('Premium Chunk White Chicken In Broth', 548.0),
#  ('Baking Soda', 0.0),
#  ('Hard Filled Candy', 1795.0),
#  ('Brutti E Buoni Alle Mandorle', 1841.0),
#  ('Barbecue Sauce', 665.0),
#  ('Coconut Butter', 2971.0),
#  ("Coconut Tree Brand, Pho', Pho Soup Seasoning Spice Cube", 1163.0),
#  ('Coconut Tree Brand, Pho Ga Spice Cube', 1163.0),
#  ('Coconut Tree Brand, Kho Tieu Seasoning Spice Cube', 1163.0),
#  ('Coconut Tree Brand, Spice Cube Soup Sessoning', 1163.0),
#  ('Bun Mam Soup Seasoning', 1163.0),
#  ('Coconut Tree Brand, Spice Cube, Hoanh Thanh Soup Seasoning', 1163.0),
#  ('Bo Kho Stewed Beef Seasoning', 1163.0),
#  ('Coconut Tree Brand, Bun Bo Hue Spice Cube', 1163.0),
#  ('Coconut Tree Brand, Vegetarian "Bo Kho" Seasoning', 1163.0),
#  ('Coconut Tree Brand, Hu Tieu, Spice Cube, Vegetarian Hu Tieu Soup Seasoning',
#   1163.0),
#  ('Pho Chay Spice Cube', 1301.0),
#  ('Coconut Tree Brand, Spice Cube Seasoning', 1163.0),
#  ('Coconut Tree Brand, Spice Cube Soup Seasoning', 1163.0),
#  ('Coconut Tree Brand, Vegetarian Soup Cubes', 1163.0),
#  ('Crab Soup Seasoning, Spice Cube', 1163.0),
#  ('Extra Virgin Olive Oil', 3586.0),
#  ('Spicy Black Bean Dip', 448.0),
#  ('Cashews, Sesame And Pistachios Brittle Slice', 2201.0),
#  ('Chocolart, Assorted Milk Chocolate Pralines', 2247.0),
#  ('Passion, Assorted Milk Chocolate', 2201.0),
#  ('Assorted Chocolate Pralines', 2301.0),
#  ('Milk Chocolate Balls With Cream And Chocolate', 2293.0),
#  ('Chocolate Ball', 1891.0),
#  ('Chocolate Balls Filled With Milk Cream And Chocolate', 2301.0),
#  ('Merry Christmas Chocolate Balls', 2360.0),
#  ('Merry Christmas Chocolate Balls Filled With Praline Cream', 2301.0),
#  ('Merry Christmas Minis Chocolate Bar', 2406.0),
#  ('Milk Chocolate', 2423.0),
#  ('Chocolate Cookies', 2209.0),
#  ('Chutney, Hot Mango Hot', 996.0),
#  ('Dopiaza Curry Simmer Sauce, Mild', 418.0),
#  ('Red Curry Spice', 540.0),
#  ('Coconut Ginger Rice', 1674.0),
#  ('Sweet Chili Sauce', 987.0),
#  ('Top Ramen Noodle Soup', 1891.0),
#  ('Extra Hot Chinese Mustard', 837.0),
#  ('Organic Nine Grain All Natural Bread', 1167.0),
#  ('Organic 100% Whole Wheat', 975.0),
#  ('Organic Great Seed', 1071.0),
#  ('Mountain White', 929.0),
#  ('Great Seed Bread', 1151.0),
#  ('Fruit Spredad, Strawberry', 0.0),
#  ('Fruit Spread, Raspberry', 0.0),
#  ('Long Grain Enriched Rice', 1515.0),
#  ('Sweet Cherry Peppers', 209.0),
#  ('Deli-Sliced Hot Jalapeno Peppers', 71.0),
#  ('21 Seasoning Salute', 0.0),
#  ('Crushed Garlic', 837.0),
#  ('Condensed Soup, Tomato', 314.0),
#  ('Sauce Mix', 2301.0),
#  ('Golden Curry, Sauce Mix', 2301.0),
#  ('Fried Rice Seasoning Mix', 1569.0),
#  ('Whole Durum Wheat Cous Cous', 1393.0),
#  ('Japanese Style Noodles & Chicken Flavored-Soup', 1925.0),
#  ('Whole Wheat Flour Tortillas', 1021.0),
#  ('Flour Tortillas', 1209.0),
#  ('Lemon Curd', 1393.0),
#  ('Bunge, Clear Liquid Soybean Frying Oil', 3887.0),
#  ('Panda Brand, Oyster Flavored Sauce', 552.0),
#  ('Almonds Cookies', 2230.0),
#  ('Quiche, Spinach, Mushroom & Cheese', 1134.0),
#  ('Mexicaine Quiche', 1230.0),
#  ('Dry Roasted & Salted Almonds', 2372.0),
#  ('Cool Beans, Catalina Bean Hummus', 895.0),
#  ('Cool Beans, Red Pepper Hummus', 895.0),
#  ('Cool Beans, Buffalo Hummus', 1197.0),
#  ('Organic Tortellini Pasta', 1088.0),
#  ('Nuovo Pasta, Organic Ravioli, Butternut Squash', 795.0),
#  ('Organic Ravioli', 837.0),
#  ('Ravioli Five Cheese', 1155.0),
#  ('Tender Spinach, Whipped Potatoes & Cheddar Cheese In A Pierogi Shell',
#   920.0),
#  ('Pierogi', 1004.0),
#  ('Ravioli', 837.0),
#  ('Oven Roasted Pumpkin Pasta Purse', 1046.0),
#  ('Tomato, Basil & Mozzarella Rovioli', 711.0),
#  ('Ravioli', 837.0),
#  ('Shrimp Scampi Ravioli', 795.0),
#  ('Sweet Basil Pesto Ravioli', 711.0),
#  ('Gold Fish Shaped Ravioli!', 1130.0),
#  ('Kale, Hummus & Chicckpea Ravioli', 879.0),
#  ('Classic Cheese Ravioli', 753.0),
#  ('Chocolate Cream Dip Wiht Crispy Craker Sticks', 2188.0),
#  ('Yan Yan Crispy Cracker Stick, Strawberry', 2226.0),
#  ('Yam Yam Double Cream, Chocolate, Strawberry', 2280.0),
#  ('Hello Panda, Choco Biscuits With Choco Cream, Double Choco', 2230.0),
#  ('Hellow Panda, Biscuits With Choco Cream', 2230.0),
#  ('Biscuits With Strawberry Cream', 2230.0),
#  ('Hello Panda, Biscuits With Choco Cream', 2222.0),
#  ('Hello Panda Biscuits With Strawberry Cream', 2251.0),
#  ('Yan Yan Cream Dip', 2188.0),
#  ('Chicago Flats, Whole Grain Artisan Flatbread', 1628.0),
#  ('Chicago Flats, Rosemary & Sea Salt Artisan Flatbread', 1628.0),
#  ('Chicago Flats, Gourmet Flatbread, Sea Salt', 1628.0),
#  ('Greek Salad Dressing & Marinade', 2987.0),
#  ('Gazebo Room, Balsamic Vinaigrette', 2690.0),
#  ('Gazebo Room, Lite Greek Salad Dressing & Marinade', 1197.0),
#  ('Lentils', 272.0),
#  ('Chocolate Bites', 1841.0),
#  ("Bill Knapp's, Old-Fashioned Cinnamon-Sugar Doughnut Holes", 1293.0),
#  ('Dunkers, Cinnamon-Sugar', 1377.0),
#  ("Bill Knapp's, Iced Toaster Bread, Cinnamon Raisin", 1343.0),
#  ("Bill Knapp's, Iced Toaster Bread, Cranberry Cherry", 1343.0),
#  ("Bill Knapp's, Iced Toaster Bread, Cranberry-Orange", 1343.0),
#  ("Classic 7'' Chocolate Cake", 1079.0),
#  ('Crystallized Ginger Candy', 1506.0),
#  ('Chewy Ginger Candy', 1745.0),
#  ('Ginger Candy Sweetened With Raw Cane', 4435.0),
#  ('Meal Replacement Shake Mix, Creamy Milk Chocolate', 1770.0),
#  ('Peanut Butter', 1820.0),
#  ('Chocolate Cookie Dough Protein Meal Bars', 1611.0),
#  ('Slim Fast, Protein Meal Bars, Chocolate Fudge Brownie', 1611.0),
#  ('Protein Meal Bar', 1674.0),
#  ('Dark Chocolate Sea Salt', 1766.0),
#  ('Slimfast, Advanced Nutrition Smoothie', 1770.0),
#  ('100 Calorie Snack Bites, Peanut Butter Chocolate', 1820.0),
#  ('Slimfast, 100 Calorie Snack Drizzled Crisps, Cinnamon Bun Swirl', 1494.0),
#  ('100 Calorie Snacks Drizzled Crisps, Cinnamon Bun Swirl', 1494.0),
#  ("100 Calorie Snacks Drizzled Crisps, S'Mores", 1494.0),
#  ('100 Calorie Snacks Baked Crisps, Mesquite Bbq', 1494.0),
#  ('100 Calorie Snacks Baked Crisps, Sour Cream & Onion', 1494.0),
#  ('Slimfast, Baked Chips, Mesquite Bbq', 1494.0),
#  ('Slimfast, Advanced Nutrition Baked Chips, Sour Cream & Onion`', 1494.0),
#  ('Slimfast, Baked Chips, Mesquite Bbq', 1494.0),
#  ('Slimfast, 100 Calorie Snack Baked Chips, Sour Cream & Onion', 1494.0),
#  ('Slimfast, Drizzled Crisps, Cinnamon Bun Swirl', 1494.0),
#  ("Slim Fast, Drizzled Crisps Snack Bars, S'Mores", 1494.0),
#  ('Wicklein, Brown Gingerbread', 1536.0),
#  ('Roasted Garlic Salsa, Roasted Garlic', 138.0),
#  ('Barbecue Sauce', 381.0),
#  ('Hot Barbecue Sauce', 381.0),
#  ('Special Barbecue Sauce', 406.0),
#  ('Whole Grain', 674.0),
#  ('Special Blend Taco Sauce', 138.0),
#  ('Double Chocolate Mini Eclairs', 1297.0),
#  ('Belgian Large Coconut Macaroons', 1833.0),
#  ('The Original Macaroon', 1695.0),
#  ('Belgian Mini Cream Puffs', 1506.0),
#  ('Barbeque Sauce, Maple', 715.0),
#  ('Penne Pasta', 1443.0),
#  ('Cut Ziti Pasta', 1443.0),
#  ('Long Grove Confectionery Co., Chocolate Fudge', 1674.0),
#  ('Long Grove Confectionery Co, Rocky Road Fudge', 1778.0),
#  ('Long Grove Confectionery Co., Halloween Chocolate Pop', 2238.0),
#  ('Long Grove Confectionery Co., Day To Dead Chocolate Skull', 2192.0),
#  ('Long Grove Confectionery Co., Spooky Treats, Mini Pretzel Twists', 1954.0),
#  ('Long Grove Confectionery Co, Dark Chocolate, Peppermint Creames', 1870.0),
#  ('Long Grove Confectionery Co., Milk Chocolate, Coconut Caramel', 2092.0),
#  ('Long Grove Confectionery Co., Peanut Butter Melts', 2238.0),
#  ('Long Grove Confectionery Co, Creamy White Pretzel Twists', 1891.0),
#  ("Long Grove Confectionery Co., St. Pat's Mini Pretzels", 1992.0),
#  ('Long Grove Confectionery Co., St.Pats Nonpareils Candy', 2151.0),
#  ('Long Grove Confectionery Co., Creamy White Confetti Cookies', 2092.0),
#  ('Long Grove Confectionery Co, Pastel Mint Nonpareils', 2092.0),
#  ('Long Grove Confectionery Co, Spring Nonpareils', 1987.0),
#  ('Solid Chocolate Rabbit', 2251.0),
#  ('Long Grove Confectionery Co., Corn, Chocolatey Drizzled Caramel', 1536.0),
#  ('Long Grove Confectionery Co., Creamy White Drizzled Caramel Corn', 1674.0),
#  ('Long Grove Confection Co., Chicago Snack Mix, Cheese & Caramel Popcorn',
#   2092.0),
#  ("Long Grove Confectionery Co, Cookies N' Cream Bark", 2092.0),
#  ('Long Grove Confectionery Co, Happy Birthday Pop', 2238.0),
#  ('Long Grove Confectionery Co, Congratulations Pop', 2201.0),
#  ('Long Grove Confectionery Co, Pretzel Twists, Milk Chocolate', 1954.0),
#  ('Creamy White Pretzel Twists', 2092.0),
#  ('Long Grove Confectionery Co., Graham Crackers, Milk Chocolate', 2243.0),
#  ('Dark Chocolate Sea Salt Caramels', 1695.0),
#  ('Long Grove Confectionery Co., Myrtles, Milk Chocolate Pecan', 2092.0),
#  ('Milk Chocolate Pecan Myrtles', 2293.0),
#  ('Milk Chocolate Pecan Myrtles', 2293.0),
#  ("Milk Chocolate S'Mores", 2033.0),
#  ("Long Grove Confectionery Co., Cupid's Pretzels", 1987.0),
#  ('Long Grove Confectionery Co., Pretzels, Cherry', 2301.0),
#  ('Pretzels, Yogurt', 1812.0),
#  ('Pretzels', 1954.0),
#  ('Double Dip Penuts', 2230.0),
#  ('Chocolate Malt Balls', 2142.0),
#  ('All Natural Chocolate Raisins', 1795.0),
#  ('Dark Chocolate Almonds', 2264.0),
#  ('Dark Chocolate Nonpareils', 2151.0),
#  ('Chocolate Almonds', 1807.0),
#  ('Ultimate Brown Bag Apple Pie', 1059.0),
#  ('Cracker Crisps Sesame Mini Crackers', 2092.0),
#  ('Cracker Crisps, Sour Creme & Onion', 1795.0),
#  ('Small Red Beans', 699.0),
#  ('Chunky Salsa', 71.0),
#  ('The Foreign Candy Company, Rip Rolls Candy, Blue Raspberry', 1360.0),
#  ('Sorbet Gourmet', 435.0),
#  ('Sorbet, Dutch Chocolate', 481.0),
#  ('Sorbet, Mixed Berry', 435.0),
#  ('Sorbet', 435.0),
#  ('Sorbet, Coconut', 665.0),
#  ('Biscotti Decoratie Wafers', 1962.0),
#  ('Delice Biscotti', 1954.0),
#  ('Party Mix Assorted Biscuits', 1962.0),
#  ('Biscuits With Rich Rice Flour Decorated With Cocoa', 2000.0),
#  ('Squire Boone Village, Middle Size Heart Pop, Cherry', 1674.0),
#  ('Squire Bone Village, Christmas Tree Lollipop, Peppermint', 1661.0),
#  ('100% desert mesquite honey', 1197.0),
#  ('Phong Kee, Hot Roasted Peanuts', 2063.0),
#  ('Hig Hagemann, Mixed Wafers', 2368.0),
#  ('Sweet Relish', 556.0),
#  ('Dill Relish', 0.0),
#  ('Jalapeno Slices', 75.0),
#  ('Sliced Jalapeno Peppers', 0.0),
#  ('Sweet Baby Gherkins', 523.0),
#  ('Hot Dog Relish', 556.0),
#  ('Squeeze Sweet Relish', 556.0),
#  ('Squeeze Sweet Relish', 0.0),
#  ('Hot Dog Relish', 556.0),
#  ('Sweet India Relish', 556.0),
#  ('Hamburger Dill Chips', 0.0),
#  ('Sweet Relish', 556.0),
#  ('Sweet Gherkins', 523.0),
#  ('Baby Dills', 75.0),
#  ('Sandwich Stuffers Kosher Dill', 75.0),
#  ('Hamburger Dill Chips', 0.0),
#  ('Sandwich Stuffers', 297.0),
#  ('Dills', 0.0),
#  ('Old-Fashioned Sweet Bread & Butter Chips', 372.0),
#  ('Kosher Hamburger Dill Chips', 75.0),
#  ('Kosher Dill Spears', 75.0),
#  ('Old-Fashioned Sweet Bread & Butter Chips', 372.0),
#  ('Kosher Dill Spears', 75.0),
#  ('Kosher Dills', 75.0),
#  ('Kosher Baby Dills', 75.0),
#  ('Kosher Dills', 75.0),
#  ('Kosher Dill Spears', 75.0),
#  ('Pepperoncini', 151.0),
#  ("Sweet 'N' Hot Salad Peppers", 598.0),
#  ('Sliced Pepperoncini', 151.0),
#  ('Hot Banana Pepper Rings', 151.0),
#  ('Mild Banana Pepper Rings', 151.0),
#  ('Sweet Relish', 0.0),
#  ('Sweet Gherkins', 0.0),
#  ('Bread & Butter Chips', 0.0),
#  ('Sandwich Snuffers Bread & Butter', 0.0),
#  ('Bread & Butter Spears', 0.0),
#  ('Hamburger Dill Chips', 75.0),
#  ('Little Sister Thin Dill Chips', 0.0),
#  ('Kosher Hamburger Dill Chips', 75.0),
#  ('Fresh Pack Kosher Dills', 75.0),
#  ('Hamburger Dill Chips Pickles', 0.0),
#  ('Dills', 0.0),
#  ('Kosher Dill', 75.0),
#  ('Sandwich Stuffers, Old-Fashioned Sweet Bread & Butter', 297.0),
#  ('Sandwich Stuffers Kosher Dill', 75.0),
#  ('Kosher Petite Dills', 75.0),
#  ('Bread Butter Chips', 372.0),
#  ('Sweet Relish', 556.0),
#  ('Sweet Gherkins', 523.0),
#  ('Kosher Drill Spears', 75.0),
#  ('Bread & Butter Chips, Chipotle', 372.0),
#  ('Chipotle Sweet Relish, Sweet Smoky', 556.0),
#  ('Polish Dill Spears Made With Sea Salt', 75.0),
#  ('Petite Snack Crunchers, Sweet Petite', 598.0),
#  ('Bread & Butter Chips Pickles, Hint Of Salt', 372.0),
#  ('Sweet Relish, Reduced Sodium', 556.0),
#  ('Kosher Dill Spears Pickles', 75.0),
#  ('Kosher Baby Dills', 75.0),
#  ('Petite Snack Crunchers, Buffalo Kosher Dills, Hot Sauce Flavored', 75.0),
#  ('Kosher Baby Dills, Buffalo, Hot Sauced Flavored', 75.0),
#  ('Kosher Baby Dills', 75.0),
#  ('Kosher Petite Dills', 75.0),
#  ('Kosher Baby Dills Made With Sea Salt', 75.0),
#  ('Kosher Petite Dills Made With Sea Salt', 75.0),
#  ('Delicatessen Style Mild Banana Pepper Rings', 151.0),
#  ('Diced Jalapeno Peppers', 0.0),
#  ('Delicatessen Style Jalapeno Slices', 75.0),
#  ('Delicatessen Style Pepperoncini', 151.0),
#  ('Roasted Red Peppers', 75.0),
#  ('Marinated Roasted Peppers Olive Oil & Garlic', 151.0),
#  ('Bread & Butter Chips', 372.0),
#  ('Sweet Gherkins Pickles', 598.0),
#  ('Kosher Petite Dills Simply Pickles', 75.0),
#  ('Simply Pickles, Kosher Dill Sandwich Stuffers', 75.0),
#  ('Simply Pickles, Bread & Butter Sandwich Stuffers', 297.0),
#  ('Simply Pickles, Bread & Butter Chips', 372.0),
#  ('Simply Pickles, Hamburger Dill Chips', 75.0),
#  ('Sweet Relish Made With Sea Salt', 556.0),
#  ('Dill Relish', 0.0),
#  ('Deli Style Dill Relish Made With Sea Salt', 0.0),
#  ('Deli Style Sweet Relish Made With Sea Salt', 418.0),
#  ('Kosher Dill Spears Made With Sea Salt', 75.0),
#  ('Sandwich Stuffers, Kosher Dill Made With Sea Salt', 75.0),
#  ('Old-Fashioned Sweet Bread & Butter Chips Made With Sea Salt', 372.0),
#  ('Kosher Baby Dills Made With Sea Salt', 75.0),
#  ('Mini Stuffers, Hamburger Dill Chips Made With Sea Salt', 75.0),
#  ('Sandwich Stuffers, Old-Fashioned Sweet Bread & Butter Made With Sea Salt',
#   297.0),
#  ('Kosher Dills Made With Sea Salt', 75.0),
#  ('Simply Pickles, Kosher Baby Dills', 75.0),
#  ('Simply Pickles, Kosher Dill Spears', 75.0),
#  ('Kosher Dills', 75.0),
#  ('Sweet Relish', 556.0),
#  ('Flavored Bread & Butter Chips, Jalapeno', 372.0),
#  ('Reduced Sodium Sweet Relish', 556.0),
#  ('Sweet Relish', 418.0),
#  ('Pickle Pak, Kosher Dill Petites', 0.0),
#  ('Pickle Pak, Sweet Petites', 536.0),
#  ('Kosher Dills', 75.0),
#  ('Zesty Garlic Kosher Dills', 75.0),
#  ('Kosher Spears, Zesty Garlic', 75.0),
#  ('Masala Simmer Sauce', 301.0),
#  ('Burnt Sugar Browning', 941.0),
#  ('Hot Jamaican Jerk Curry Seasoning', 0.0),
#  ('Butter Beans', 481.0),
#  ('Blue Mountain Country, Garlic Escallion Allspice Seasoning', 0.0),
#  ('Oxtail Seasoning', 0.0),
#  ('Blue Mountain Country, Chicken Seasoning', 0.0),
#  ('Jamaican Jerk Seasoning', 494.0),
#  ('Jamaican Jerk Seasoning', 1674.0),
#  ('Country Brand Souse', 820.0),
#  ('Red Hots Imitation Sausage-Artificially Colored', 1209.0),
#  ("Pappy's Choice, Prime Rib Rub", 0.0),
#  ('Pepper', 0.0),
#  ('Asian Stir Fry Sauce And Marinade', 494.0),
#  ("Pappy's Choice, Garlic Herb", 0.0),
#  ("Pappy's, Lemon Pepper, Lemon", 0.0),
#  ('Excellence Dark Chocolate With Sea Salt', 2301.0),
#  ('Dark Assortment Chocolate', 2406.0),
#  ('Hello My Name Is Cookies & Cream, Milk Chocolate With Cookies And Cream Filling',
#   2301.0),
#  ('Milk Chocolate With Strawberry Cream Cheese Filling, Strawberry', 2197.0),
#  ('Minis Chocolate', 2301.0),
#  ('Dark Chocolate Truffles', 2674.0),
#  ('Lindor Assorted Chocolate Truffles', 2674.0),
#  ('Lindor, Assorted Chocolate Truffles', 2674.0),
#  ('Assorted Chocolate Truffles', 2674.0),
#  ('Classic Assorted Chocolates', 2347.0),
#  ('Milk Chocolate Truffles, Caramel', 2556.0),
#  ('Irresistibly Smooth Caramel Milk Chocolate Truffles', 2556.0),
#  ('Hens Milk Chocolate', 2272.0),
#  ('Assorted Milk Chocolates', 2377.0),
#  ('Gold Bunny Milk Chocolate', 2301.0),
#  ('Chocolate Minis', 2301.0),
#  ('Cheesecake', 2301.0),
#  ('Assorted Chocolate Mini Sticks', 2301.0),
#  ('Candy', 2347.0),
#  ('Lindor Coconut Milk Chocolate Truffles', 2674.0),
#  ('Milk Chocolate Truffles', 2556.0),
#  ('Lindor, Milk Chocolate, Caramel With Sea Salt', 2293.0),
#  ('Milk Chocolate Caramels', 2092.0),
#  ('Selections Extra Dark Chocolate Truffles', 2536.0),
#  ('Milk Chocolate Hazelnut Truffles', 2565.0),
#  ('Selections Milk Chocolate Pecan Caramel', 2092.0),
#  ('Excellence Dark Chocolate, Lemon', 2197.0),
#  ('Lindor White Chocolate Truffles', 2556.0),
#  ('Lindor Dark Chocolate Truffles', 2674.0),
#  ('Lindor Dark Chocolate Truffles', 2674.0),
#  ('Milk Chocolate With A Salted Caramel Filling', 2038.0),
#  ('Dark Chocolate Cookie', 2146.0),
#  ('Milk Chocolate With Salted Caramel-Filling', 2092.0),
#  ('Dark Chocolate With A Creamy Chocolate Filling And Dark Cookie Piecescookie',
#   2197.0),
#  ('Hello My Name Is Milk Chocolate Stick', 2251.0),
#  ('Extra Dark Chocolate', 2406.0),
#  ('Dark Chocolate Bars', 1987.0),
#  ('Lindor, Assorted Chocolate Truffles', 2674.0),
#  ('Lindor, Assorted Chocolate Truffles', 2674.0),
#  ('Lindor, Irresistibly Smooth White Chocolate Truffles, Peppermint', 2674.0),
#  ('Lindor, Peppermint White Chocolate Truffles', 2674.0),
#  ('Peppermint White Chocolate Truffles', 2674.0),
#  ('Lindor Chocolate Truffles', 2674.0),
#  ('Lindor White Chocolate Truffels, Peppermint', 2674.0),
#  ('Assorted Chocolate Mini Sticks', 2301.0),
#  ('Caramel Brownie, Milk Chocolate With Hazelnut And Caramel Brownie Filling',
#   2301.0),
#  ('Milk Chocolate Truffles', 2556.0),
#  ('Milk Chocolate With Strawberry Cream Cheese Filling', 2301.0),
#  ('Milk Chocolate With Hazelnut And Caramel Brownie', 2301.0),
#  ('Assorted Chocolate Mini Sticks', 2301.0),
#  ('Classic Assorted Dark Chocolate', 2360.0),
#  ('Classic Assorted Nuts & Caramel', 2347.0),
#  ('Lindor Caramel Milk Chocolate Pieces', 2573.0),
#  ('Assorted Chocolate Minis Sticks', 2301.0),
#  ('Icicle Assorted Milk Chocolates', 2431.0),
#  ('Truffles', 2674.0),
#  ('Lindor Milk Chocolate Truffles', 2556.0),
#  ('Peppermint White Chocolate Truffles', 2674.0),
#  ('Lindor, Assorted Chocolate Truffles, Peppermint', 2674.0),
#  ('Master Swiss Chocolatier', 2389.0),
#  ('Signature Selections Extra Dark Chocolate Truffles', 2536.0),
#  ('Signature Selections, Milk Chocolate Caramel', 1891.0),
#  ('Milk Chocolate Hearts', 2439.0),
#  ('Gourmet Truffles', 2615.0),
#  ('Milk & Dark Chocolate', 2347.0),
#  ('Frog Prince Milk Chocolate', 2406.0),
#  ('Lindor Truffles', 2489.0),
#  ('Lindor, Assorted Chocolate Truffle Eggs', 2531.0),
#  ('Lindor, Mini Eggs Truffle, Milk Chocolate', 2552.0),
#  ('Solid Milk Chocolate Eggs', 2251.0),
#  ('Gourmet Truffles', 2615.0),
#  ('Assorted Chocolates', 2448.0),
#  ('Lindor, Assorted Chocolate Truffles', 2674.0),
#  ('Milk Chocolate', 2301.0),
#  ('Chocolate Minis', 2301.0),
#  ('Chocolate Minis', 2301.0),
#  ('Lindor, Assorted Chocolate Truffles, Assorted', 2674.0),
#  ('Lindor, Milk Chocolate Truffles', 2556.0),
#  ('Assorted Chocolates', 2448.0),
#  ('Strawberry And Cream White Chocolate Truffles', 2531.0),
#  ('Excellence Pineapple - With Pieces Of Pineapple And Carmelized Hazelnuts',
#   2197.0),
#  ('Dark Chocolate With Blackberry Pieces And Acai, Blackberry With Acai',
#   2197.0),
#  ('Classic Recipe Salted Pretzel', 2197.0),
#  ('Milk Chocolate Covered Pretzel Rounds', 2197.0),
#  ('Milk Chocolate Toffee Bites', 2301.0),
#  ('Dark Chocolate Covered Mint Cubes', 2197.0),
#  ('Lindor, Dark Chocolate Truffles, Caramel Sea Salt', 2791.0),
#  ('Milk Chocolate Truffles', 2615.0),
#  ('Lindor, White Chocolate Truffles', 2615.0),
#  ('Dark Chocolate Truffles', 2615.0),
#  ('Milk Chocolate Truffles', 2615.0),
#  ('Milk Chocolate Truffles', 2615.0),
#  ('Lindor, Lindor Milk Chocolate Truffles', 2615.0),
#  ('Lindor, Lindor White Chocolate Truffles, Peppermint', 2674.0),
#  ('Lindor, Dark Chocolate Truffles, Orange', 2674.0),
#  ('Lindor, Milk Chocolate Truffles, Caramel', 2556.0),
#  ('Lindor, Dark Chocolate Truffles', 2674.0),
#  ('Lindor Caramel', 2556.0),
#  ('Assorted Chocolate Truffles', 2674.0),
#  ('Lindor, Milk Chocolate Truffles', 2556.0),
#  ('Lindor, Dark Chocolate Truffles', 2674.0),
#  ('Lindor, White Chocolate Truffles', 2674.0),
#  ('', 2406.0),
#  ('Assorted Chocolate Mini Sticks', 2301.0),
#  ('Assorted Chocolate Truffles', 2674.0),
#  ('Milk Chocolate Caramels', 1992.0),
#  ('Selections Milk Chocolate', 2092.0),
#  ('Extra Dark Chocolate Truffles', 2536.0),
#  ('Irresistibly Smooth Milk Chocolate Truffle', 2556.0),
#  ('Lindor, Assorted Chocolate Truffles', 2674.0),
#  ('White Chocolate Truffles', 2674.0),
#  ('Lindor, Extra Dark Chocolate Truffles, Dark Peppermint', 2674.0),
#  ('Lindor, Milk And White Milk Chocolate Truffles', 2674.0),
#  ('Dark Chocolate', 2301.0),
#  ('Milk Chocolate Elf', 2406.0),
#  ('Mini Milk Chocolate Ball', 2314.0),
#  ('Assorted Milk Chocolates', 2377.0),
#  ('Milk Chocolate With Pieces Of Popcorn And A Creamy Filling', 2360.0),
#  ('Sweet Popcorn Milk Chocolate', 2301.0),
#  ('Lindor, Assorted Chocolate Truffles', 2674.0),
#  ('Assorted Chocolate Truffles', 2674.0),
#  ('Lindor, Dark Chocolate Truffles', 2674.0),
#  ('Lindor, Milk Chocolate Truffles', 2556.0),
#  ('Milk Chocolate Truffles', 2674.0),
#  ('Lindor, Dark Chocolate Truffles, Peppermint', 2674.0),
#  ('Lindor Milk Chocolates Truffles', 2556.0),
#  ('Lindor, Assorted Chocolate Truffles', 2674.0),
#  ('Lindor, Milk Chocolate Truffles, Milk And White', 2674.0),
#  ('Irresistibly Smooth White Chocolate Truffles', 2674.0),
#  ('Strawberries And Cream White Chocolate Truffles', 2674.0),
#  ('Dark Chocolate, Pomegranate', 2092.0),
#  ('Lindor, Assorted Chocolate Truffles', 2674.0),
#  ('Lindor, Assorted Chocolate Truffles, Peppermint', 2674.0),
#  ('Lindor, Milk Chocolate Truffles', 2556.0),
#  ('Lindor, Assorted Chocolate Truffles', 2674.0),
#  ('Milk Chocolate With Popping Raspberry And Cream Filling, Milk Chocolate',
#   2301.0),
#  ('Milk Chocolate With Vanilla And Chocolate Fillings And Almond Pieces',
#   2301.0),
#  ('Caramel Milk Chocolate Truffles', 2556.0),
#  ('Milk And White Milk Chocolate Truffles', 2674.0),
#  ('Gold Bunny', 2301.0),
#  ('Milk Chocolate Covered Hello Pretzel Rounds Bite', 2197.0),
#  ('Irresistibly Smooth Strawberries And Cream White Chocolate Truffles',
#   2674.0),
#  ('Milk Chocolate', 2301.0),
#  ('Lindor, White Chocolate Truffles, Strawberry & Cream', 2674.0),
#  ('Sprungli, Assorted Chocolate Truffles', 2674.0),
#  ('Dark Chocolate With Pieces Of Lychee', 2197.0),
#  ('Supreme Dark Chocolate', 2510.0),
#  ('Dark Chocolate', 2092.0),
#  ('Lindor, Chocolate Truffles, Assorted', 2674.0),
#  ('Lindor, Assorted Chocolate Truffles', 2674.0),
#  ('Lindor, White Chocolate Truffles', 2615.0),
#  ('Lindor Milk Chocolate Truffles, Milk', 2556.0),
#  ('Lindor, Milk Chocolate Truffles, Milk And White', 2674.0),
#  ('Signature Collection, Premium Chocolates', 2431.0),
#  ('Lindor, Assorted Chocolate Truffles', 2674.0),
#  ('Lindor, Milk Chocolate Truffle Eggs', 2540.0),
#  ('Lindor Chocolate Truffles, Strawberry & Cream', 2674.0),
#  ('Irresistibly Smooth Milk Chocolate Truffles', 2556.0),
#  ('Lindor Chocolate Truffles, Assorted', 2674.0),
#  ('Crunchy Cookie Bites', 2197.0),
#  ('Smoothie', 2197.0),
#  ('Milk Chocolate With A Coffee And Cream Filling', 2360.0),
#  ('Lindor, Milk And White Milk Chocolate Truffles', 2674.0),
#  ('Chocolate Wafer', 2092.0),
#  ('Lindor, White Chocolate Truffles, Strawberries And Cream', 2674.0),
#  ('Gold Bunny & Friends, Milk Chocolate', 2389.0),
#  ('Chocolate Truffles Eggs', 2489.0),
#  ('Lindor, Chocolate Truffle Eggs, Coconut', 2590.0),
#  ('Milk Chocolate', 2406.0),
#  ('Lindor - Milk Chocolate Truffles', 2556.0),
#  ('White Chocolate Truffles', 2674.0),
#  ('Irresistibly Smooth White Chocolate Truffles', 2531.0),
#  ('Lindor, Pumpkin Spice Milk Chocolate Truffles', 2556.0),
#  ('Lindor, Milk Chocolate Truffles, Pumpkin Spice', 2556.0),
#  ('Lindor Milk Chocolate Truffle Bar', 2531.0),
#  ('Lindor Milk Chocolate Truffles', 2556.0),
#  ('Lindor Assorted Chocolate Truffles', 2674.0),
#  ('Lindor, Milk Chocolate Truffles', 2674.0),
#  ('Elf Milk Chocolate', 2301.0),
#  ('Lindor, Milk Chocolate Truffle Bars', 2531.0),
#  ('Black Beans', 368.0),
#  ("Tyler Sash's Favorite Seasoning Mix", 0.0),
#  ('Italian Olive Oil Spray', 0.0),
#  ('Mints, Candy Cane', 1657.0),
#  ('Rocher, Hazelnut Chocolates', 2531.0),
#  ('Scary Sweets Mints, Grape & Cherry', 1623.0),
#  ('Flavored Mints, Grape', 1623.0),
#  ('Flavored Mints, Candy Cane', 1623.0),
#  ('Made In Ireland', 1623.0),
#  ('Candy Cane', 1623.0),
#  ('Flavored Mints', 1623.0),
#  ('Summer Ice Pop Mint', 1623.0),
#  ('Freshmints', 1623.0),
#  ('Fruit Mints', 1623.0),
#  ('Freshmints', 1623.0),
#  ('Mints', 1623.0),
#  ('Flavored Mints', 1623.0),
#  ('Mints', 1623.0),
#  ('Flavored Mints, Grrr...Een Apple', 1623.0),
#  ('Mummy Mints, Orange', 1623.0),
#  ('Snowman Fruit Mix Mints, Lime & Berry', 1623.0),
#  ('Mints, Grape', 1623.0),
#  ('Minions Mints, Banana', 1623.0),
#  ('Fruit Adventure', 1623.0),
#  ('Fruit Adventure, Mixed', 1623.0),
#  ('Freshmints', 1623.0),
#  ('Mints, Orange', 1623.0),
#  ('Flavored Mints, Berry Cherry', 1623.0),
#  ('Mints', 1623.0),
#  ('Freshmints', 17.0),
#  ('Orange Mints, Orange', 1623.0),
#  ('Flavored Mints, Wintergreen', 1623.0),
#  ('Fruit Mints, Strawberry Fields', 1623.0),
#  ('Fruit Adventure Mints', 1623.0),
#  ('Freshmints', 17.0),
#  ('Mints, Orange', 17.0),
#  ('Mints, Wintergreen', 17.0),
#  ('Freshmints', 1623.0),
#  ('Mints', 1623.0),
#  ('Flavored Mints, Fruit Adventure', 1623.0),
#  ('Mints, Wintergreen', 1623.0),
#  ('Flavored Mints, Fruit Adventure', 1623.0),
#  ('Freshmints', 1623.0),
#  ('Flavored Mints, Orange', 1623.0),
#  ('Flavored Mints, Berry Cherry', 1623.0),
#  ('Mints', 1623.0),
#  ('Flavored Mints, Grape', 1623.0),
#  ('Freshmints', 1623.0),
#  ('Minions Mints, Banana', 1623.0),
#  ('Minions Mints, Banana', 1623.0),
#  ('Flavored Mints, Spearmint Mix', 1623.0),
#  ('Flavored Mints, Grape', 1623.0),
#  ('Mixers Mints, Cherry Cola', 1623.0),
#  ('Mixers Mints, Peach, Lemonade', 1623.0),
#  ('Flavored Mints, Strawberry', 1623.0),
#  ('Flavored Mints, Fruit Adventure', 1623.0),
#  ('Freshmints', 1623.0),
#  ('Flavored Mints, Orange', 1623.0),
#  ('Flavored Mints, Wintergreen', 1623.0),
#  ('Mints, Orange, Fruit Adventure, Wintergreen', 1623.0),
#  ('Milk Chocolate', 2531.0),
#  ('Rocher, Fine Hazelnut Chocolates', 2531.0),
#  ('Rocher, Fine Hazelnut Chocolates', 2531.0),
#  ('Rocher, Fine Hazelnut Chocolates', 2531.0),
#  ('Rocher, Fine Hazelnut Chocolates', 2531.0),
#  ('Rocher, Fine Hazelnut Chocolates', 2531.0),
#  ('Rocher, Fine Hazelnut Chocolates', 2531.0),
#  ('Fine Hazel Nut Chocolates', 2423.0),
#  ('Rocher, Fine Hazelnut Chocolates', 2531.0),
#  ('Rocher, Fine Hazelnut Chocolates', 2531.0),
#  ('Rocher, Fine Hazelnut Chocolates', 2531.0),
#  ('Rocher, Hazelnut Chocolates', 2531.0),
#  ('Rocher, Fine Hazelnut Chocolates', 2531.0),
#  ('Fine Hazelnut Chocolates', 2423.0),
#  ('Rocher', 2531.0),
#  ('Raffaello, Almond Coconut Treat', 2648.0),
#  ('Raffaello, Almond Coconut Treat', 2648.0),
#  ('Fine Assorted Confection Chocolates', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fine Assorted Congections', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fine Assorted Collections', 2510.0),
#  ('Fine Assorted Conefections', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fine Assorted Confections', 2510.0),
#  ('Fererro, Nutella, B-Ready Filled Wafer Bars', 2092.0),
#  ('Fine Assorted Confection', 2510.0),
#  ('Eggs Chocolate Covered Crispy Eggs, Hazelnut', 2406.0),
#  ('Eggs Chocolate Covered Crispy Eggs, Cocoa', 2301.0),
#  ('Hazelnut Spread + Breadsticks', 2171.0),
#  ('Hazelnut Spread + Breadsticks', 2171.0),
#  ('Hazelnut Spread + Pretzel Sticks', 2092.0),
#  ('12 Pack Hazelnut Spread + Breadsticks', 2171.0),
#  ('Nutella, Hazelnut Spread With Cocoa', 2264.0),
#  ('Nutella, Hazelnut Spread With Cocoa', 2264.0),
#  ('Nutella', 2260.0),
#  ('Mountain Pure, Coconut Chips', 2406.0),
#  ('Chicken Noodle Soup', 151.0),
#  ('Spaghetti Sauce, Roasted Garlic', 234.0),
#  ('Mushroom & Herb Risotto', 1494.0),
#  ('Apricot Butter', 615.0),
#  ('Hu, Crunchy Chocolate Bar, Banana', 1954.0),
#  ('Hu Simple Chocolate Bar', 2230.0),
#  ('Get Back To Human, Crunchy Fig Chocolate Bar', 2092.0),
#  ('Get Back To Human, Chocolate Bar, Crunchy Mint', 2230.0),
#  ('Get Back To Human, Chocolate Bar, Almond Butter + Puffed Quinoa', 2372.0),
#  ...]

# %%
cals = [product['energy_100g'] for product in products]
#cals

# %%
sum(cals) / len(cals)
# Out:
# 1222.9132608811217

# %%
np.mean(cals)
# Out:
# 1222.9132608811217

# %% [markdown]
# <details>
#             <summary><b><u>Answer</u></b></summary>
#
# ```python
# cals = [product['energy_100g'] for product in products]
#
# sum(cals) / len(cals)
# ```
# </details>

# %% [markdown]
# ## Question 3: What is the average amount of sugar per 100g in foods that are more than 1000 calories per 100g?

# %%
# Your work here
over_1000 = [product['sugars_100g'] for product in products if product['energy_100g'] > 1000]
np.mean(over_1000)
# Out:
# 23.2846051342134

# %% [markdown]
# <details>
#             <summary><b><u>Answer</u></b></summary>
#
# ```python
# prods_over_1000cal = [product for product in products if product['energy_100g'] > 1000]
# sugar = [product['sugars_100g'] for product in prods_over_1000cal]
# sum(sugar) / len(sugar)
# ```
# </details>

# %% [markdown]
# ## Question 4: How many foods were added (created) in each year?

# %%
years = [product['year'] for product in products]
unique_years = set(years)

# %%
unique_years
# Out:
# {2012, 2013, 2014, 2015, 2016, 2017}

# %%
years.count(2012)
# Out:
# 186

# %%
# Your work here
prod_per_year = {}
for year in unique_years:
    prod_per_year[year] = years.count(year)
prod_per_year
# Out:
# {2016: 369, 2017: 147828, 2012: 186, 2013: 571, 2014: 663, 2015: 873}

# %%
{year: years.count(year) for year in unique_years}
# Out:
# {2016: 369, 2017: 147828, 2012: 186, 2013: 571, 2014: 663, 2015: 873}

# %%
from collections import Counter

# %%
Counter(years)
# Out:
# Counter({2017: 147828, 2015: 873, 2014: 663, 2013: 571, 2016: 369, 2012: 186})

# %% [markdown]
# <details>
#             <summary><b><u>Answer</u></b></summary>
#
# ```python
# prod_year_count = {}
# list_created_years = [product['created_year'] for product in products]
# unique_prod_years = set(list_created_years)
# for unique_year in unique_prod_years:
#     num_added = len([year for year in list_created_years if year == unique_year])
#     prod_year_count[unique_year] = num_added
#
# prod_year_count
# ```
# </details>

# %% [markdown]
# # Chart the Data

# %% [markdown]
# This rendering of the data directly in the notebook is helpful, but it takes a lot of effort to read it and make sense of the trends - let's visualize the results to make this easier. More on this later!

# %%
from matplotlib import pyplot as plt

# %%
# create a figure and one plot
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 5))

# place data in a bar chart
# where the x-axis is each year and
# the y-axis is the number of products added per year
ax.bar(prod_per_year.keys(),
       prod_per_year.values())

# set axis labels
ax.set_xlabel("Year")
ax.set_ylabel("Number of Products Added")

# give the bar chart a title
ax.set_title("Foods Added to the Open Food Facts Database")

# display bar chart clearly
fig.tight_layout()

# %% [markdown]
# # Level Up: `Counter`

# %% [markdown]
# The `collections` package has a lot of useful tools for working with Python objects containing multiple elements. You can use the `Counter` class to easily count the number of values in a list.
#
# For example, let's say that for all dictionaries in `products`, we want to count how many products were added in each year.

# %%
from collections import Counter

prod_year_count = Counter([product['year'] for product in products])
prod_year_count
# Out:
# Counter({2017: 147828, 2015: 873, 2014: 663, 2013: 571, 2016: 369, 2012: 186})

# %% [markdown]
# Let's sort these by year. Since the value in `created_year` is an integer, we can use Python's built-in [`sorted`](https://docs.python.org/3/library/functions.html#sorted) function to transform the `Counter` object into a `list` of `tuples` - `(year, count)` which are sorted in ascending order by year.

# %%
sorted(prod_year_count.items())
# Out:
# [(2012, 186),
#  (2013, 571),
#  (2014, 663),
#  (2015, 873),
#  (2016, 369),
#  (2017, 147828)]

# %%
prod_year_count = sorted(prod_year_count.items())
prod_year_count
# Out:
# [(2012, 186),
#  (2013, 571),
#  (2014, 663),
#  (2015, 873),
#  (2016, 369),
#  (2017, 147828)]

# %%
sorted(prod_per_year.items(), key=lambda item: item[1])
# Out:
# [(2012, 186),
#  (2016, 369),
#  (2013, 571),
#  (2014, 663),
#  (2015, 873),
#  (2017, 147828)]

# %% [markdown]
# # Level Up: Using `datetime`

# %% [markdown]
# Python has a [`datetime`](https://docs.python.org/3.7/library/datetime.html) package that is the standard tool for handling dates and times. `datetime` objects make it easy to do fun things like subtract dates to calculate how far apart they are.

# %%
from datetime import datetime

# %%
for product in products:
    # Transform DocumentDate from string to datetime
    product["clean_date"] = datetime.strptime(product["last_modified_date"], 
                                           "%Y-%m-%d")
    
    # Add the sale year and month to each dictionary element of sales
    product["last_modified_year"] = product["clean_date"].year
    product["last_modified_month"] = product["clean_date"].month

# %% [markdown]
# Let's inspect our work

# %%
products[0]
# Out:
# {'product_name': 'Banana Chips Sweetened (Whole)',
#  'brands': '',
#  'created_date': '2017-03-09',
#  'last_modified_date': '2017-03-09',
#  'serving_size': '28.0 g',
#  'energy_100g': 2243.0,
#  'fat_100g': 28.57,
#  'carbohydrates_100g': 64.29,
#  'sugars_100g': 14.29,
#  'proteins_100g': 3.57,
#  'serving_size_g': 28.0,
#  'month': 3,
#  'year': 2017,
#  'clean_date': datetime.datetime(2017, 3, 9, 0, 0),
#  'last_modified_year': 2017,
#  'last_modified_month': 3}
